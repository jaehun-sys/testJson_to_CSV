# %%
import pandas as pd # pandas 모듈 로드
import json  # json 모듈 로드
import os

# %%
def convert_datetime(unixtime):
    """Convert unixtime to datetime"""
    import datetime
    date = datetime.datetime.fromtimestamp(unixtime).strftime('%Y-%m-%d')# %H:%M:%S')
    return date # format : str

# %%
keyword = 'test'

# %% [markdown]
# ### liked_ by 폴더 조지기

# %%
os.makedirs('./{}/{}/{}'.format(keyword,'liked_by','1916953364'),exist_ok=True) #하위폴더 생성

# %%
                       #inf_pk = []
m_id = []              #f_id = []
m_liked_by_id = []     #liked_by_id = []
                       #liked_by_fol = [] # '-'로 채우기
                       #liked_by_real = [] # '-'로 채우기

m_shortcode = []
m_liked_by_username = []

# %%
# 그 폴더 안에 파일 다 받아오기
path2 = 'G:/_2021/kCP/_파이널프로젝트/팀/data/test/liked_by/1916953364/'
file_list = os.listdir(path2)
file_list_py = [file for file in file_list if file.endswith('.json')] ## 파일명 끝이 .json인 경우

# %%
for i in file_list_py:
    with open(path2+i,'r', encoding="utf-8") as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
    
    liked_count = len(contents['data']['shortcode_media']['edge_liked_by']['edges'])
    for j in range(0,liked_count+1): #좋아요 누른 만큼 좋아요 누른 사람 파악해야돼서
        try:
            m_id.append(contents['data']['shortcode_media']['id'])
        except:
            m_id.append('-')
        try:
            m_shortcode.append(contents['data']['shortcode_media']['shortcode'])
        except:
            m_shortcode.append('-')
        
        try:
            m_liked_by_id.append(contents['data']['shortcode_media']['edge_liked_by']['edges'][j]['node']['id'])
        except:
            m_liked_by_id.append('-')
        try:
            m_liked_by_username.append(contents['data']['shortcode_media']['edge_liked_by']['edges'][j]['node']['username'])
        except:
            m_liked_by_username.append('-')
    
    
    
df5 = pd.DataFrame({"m_id":m_id, "m_shortcode":m_shortcode, "m_liked_by_id":m_liked_by_id,"m_liked_by_username":m_liked_by_username})

df5
# Out:
#                      m_id  m_shortcode m_liked_by_id m_liked_by_username
# 0     2429190161431631485  CG2N5TYAZZ9    6747371659          seonng_m_h
# 1     2429190161431631485  CG2N5TYAZZ9   38469754318          redxxchloe
# 2     2429190161431631485  CG2N5TYAZZ9   42416757776          rolrolro14
# 3     2429190161431631485  CG2N5TYAZZ9    6015470175            midfruit
# 4     2429190161431631485  CG2N5TYAZZ9    2204749269           sh_shaka_
# ...                   ...          ...           ...                 ...
# 5360  2626265713796888789  CRyXsCMprjV   39663969972            2ndmine_
# 5361  2626265713796888789  CRyXsCMprjV             -                   -
# 5362  2626265713796888789  CRyXsCMprjV      31369198       atiqah.azahar
# 5363  2626265713796888789  CRyXsCMprjV   48312972912          zzina_baby
# 5364  2626265713796888789  CRyXsCMprjV             -                   -
#
# [5365 rows x 4 columns]

# %%
path3 = 'G:/_2021/kCP/_파이널프로젝트/팀/data/test/liked_by/1916953364/liked_by_1916953364_CG2N5TYAZZ9_1.json'
with open(path3,'r', encoding="utf-8") as j:
    contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드

# %%
contents['data']['shortcode_media']['id'] # 게시글 id
# Out:
# '2429190161431631485'

# %%
contents['data']['shortcode_media']['shortcode'] # 게시글 shortcoode
# Out:
# 'CG2N5TYAZZ9'

# %%
contents['data']['shortcode_media']['edge_liked_by']['edges'][0]['node']['id'] #좋아요 누른 id
# Out:
# '6747371659'

# %%
contents['data']['shortcode_media']['edge_liked_by']['edges'][0]['node']['username']
# Out:
# 'seonng_m_h'

# %%
contents['data']['shortcode_media']['edge_liked_by']
# Out:
# {'count': 45,
#  'page_info': {'has_next_page': True,
#   'end_cursor': 'QVFEeVhEQ3g5bWRIMTVwbGJQd1F3N1lTWnU2dVU1R0x4a29RazNfMWdFRzE1M0RIakpaV1NWZzFYd3V3SmxNOXhaeFRhVFJkd2JMcExsVE0xelpQX19tUw=='},
#  'edges': [{'node': {'id': '6747371659',
#     'username': 'seonng_m_h',
#     'full_name': '홍성민',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/59320293_380440246013019_6773249054554980352_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=PRBRzdMR4BQAX_6jCTz&edm=AAo1ks0BAAAA&ccb=7-4&oh=269d3a153f2ae0479cc1146067d74faa&oe=6129CA41&_nc_sid=01e9e1',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '6747371659',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '6747371659',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/59320293_380440246013019_6773249054554980352_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=PRBRzdMR4BQAX_6jCTz&edm=AAo1ks0BAAAA&ccb=7-4&oh=269d3a153f2ae0479cc1146067d74faa&oe=6129CA41&_nc_sid=01e9e1',
#       'username': 'seonng_m_h'}}}},
#   {'node': {'id': '38469754318',
#     'username': 'redxxchloe',
#     'full_name': 'Chloe Hung',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/180147904_289836359351887_4413823029833866161_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=Pjy76yJt150AX_izrWC&edm=AAo1ks0BAAAA&ccb=7-4&oh=cbdd050498154b6ad7835ee1662f92f5&oe=6129DE72&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '38469754318',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629642860,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '38469754318',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/180147904_289836359351887_4413823029833866161_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=Pjy76yJt150AX_izrWC&edm=AAo1ks0BAAAA&ccb=7-4&oh=cbdd050498154b6ad7835ee1662f92f5&oe=6129DE72&_nc_sid=01e9e1',
#       'username': 'redxxchloe'}}}},
#   {'node': {'id': '42416757776',
#     'username': 'rolrolro14',
#     'full_name': '🕺🕺🕺',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/198637750_1132871243879430_6758824805549328279_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=zJqgZySPUjIAX-_c0NG&tn=LKYBwDhGsqlQ5ZSm&edm=AAo1ks0BAAAA&ccb=7-4&oh=be16bc6e021527f96d0d6b169b5e8b3f&oe=612A9824&_nc_sid=01e9e1',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '42416757776',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '42416757776',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/198637750_1132871243879430_6758824805549328279_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=zJqgZySPUjIAX-_c0NG&tn=LKYBwDhGsqlQ5ZSm&edm=AAo1ks0BAAAA&ccb=7-4&oh=be16bc6e021527f96d0d6b169b5e8b3f&oe=612A9824&_nc_sid=01e9e1',
#       'username': 'rolrolro14'}}}},
#   {'node': {'id': '6015470175',
#     'username': 'midfruit',
#     'full_name': '',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/118824935_813709056037644_8609552614975438022_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=f4BN6PvTeyUAX-xuudI&edm=AAo1ks0BAAAA&ccb=7-4&oh=30680296fde6cb424d3a20d9bd58f7ab&oe=61294251&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '6015470175',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629633234,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '6015470175',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/118824935_813709056037644_8609552614975438022_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=f4BN6PvTeyUAX-xuudI&edm=AAo1ks0BAAAA&ccb=7-4&oh=30680296fde6cb424d3a20d9bd58f7ab&oe=61294251&_nc_sid=01e9e1',
#       'username': 'midfruit'}}}},
#   {'node': {'id': '2204749269',
#     'username': 'sh_shaka_',
#     'full_name': '',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/219773288_334603584997568_1415228024532840201_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=ki_EsV2o1g4AX8uB-dn&tn=LKYBwDhGsqlQ5ZSm&edm=AAo1ks0BAAAA&ccb=7-4&oh=9a5d22d732d08ec0a0b872706958071d&oe=612A3630&_nc_sid=01e9e1',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '2204749269',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '2204749269',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/219773288_334603584997568_1415228024532840201_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=ki_EsV2o1g4AX8uB-dn&tn=LKYBwDhGsqlQ5ZSm&edm=AAo1ks0BAAAA&ccb=7-4&oh=9a5d22d732d08ec0a0b872706958071d&oe=612A3630&_nc_sid=01e9e1',
#       'username': 'sh_shaka_'}}}},
#   {'node': {'id': '644354678',
#     'username': 'eony_story',
#     'full_name': '경언',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/202249750_2977666709220030_3021046794633258565_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=aDfBAd0WO9IAX8RGM9D&edm=AAo1ks0BAAAA&ccb=7-4&oh=e014445f44278654da117521a8d01c1c&oe=6129B471&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '644354678',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629635313,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '644354678',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/202249750_2977666709220030_3021046794633258565_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=aDfBAd0WO9IAX8RGM9D&edm=AAo1ks0BAAAA&ccb=7-4&oh=e014445f44278654da117521a8d01c1c&oe=6129B471&_nc_sid=01e9e1',
#       'username': 'eony_story'}}}},
#   {'node': {'id': '6100495374',
#     'username': 'andkitsch',
#     'full_name': '앤드키치',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/177008140_276727564176181_2178186025266042249_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=oPCxTe0sYWUAX-PEQq8&edm=AAo1ks0BAAAA&ccb=7-4&oh=924dc5acd919aeca3f1a481de9c98a49&oe=61291E47&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '6100495374',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629622892,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '6100495374',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/177008140_276727564176181_2178186025266042249_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=oPCxTe0sYWUAX-PEQq8&edm=AAo1ks0BAAAA&ccb=7-4&oh=924dc5acd919aeca3f1a481de9c98a49&oe=61291E47&_nc_sid=01e9e1',
#       'username': 'andkitsch'}}}},
#   {'node': {'id': '590691196',
#     'username': 'qokiv',
#     'full_name': '',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/120499789_789167478560764_2310612364881279943_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=jpK5ns1cL8MAX_jwl6t&tn=LKYBwDhGsqlQ5ZSm&edm=AAo1ks0BAAAA&ccb=7-4&oh=4dfef229a601ccae2b6277d310be6283&oe=612A39B8&_nc_sid=01e9e1',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '590691196',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '590691196',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/120499789_789167478560764_2310612364881279943_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=jpK5ns1cL8MAX_jwl6t&tn=LKYBwDhGsqlQ5ZSm&edm=AAo1ks0BAAAA&ccb=7-4&oh=4dfef229a601ccae2b6277d310be6283&oe=612A39B8&_nc_sid=01e9e1',
#       'username': 'qokiv'}}}},
#   {'node': {'id': '5819793672',
#     'username': 'gyumibear',
#     'full_name': '김규미',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/152354035_751540518802874_1748547348733188496_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=Ghsa1GOP6VIAX-nVr9d&edm=AAo1ks0BAAAA&ccb=7-4&oh=93f9485def567535eea54697aceb7e40&oe=61291671&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '5819793672',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '5819793672',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/152354035_751540518802874_1748547348733188496_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=Ghsa1GOP6VIAX-nVr9d&edm=AAo1ks0BAAAA&ccb=7-4&oh=93f9485def567535eea54697aceb7e40&oe=61291671&_nc_sid=01e9e1',
#       'username': 'gyumibear'}}}},
#   {'node': {'id': '17846973431',
#     'username': 'sum.thing.moooood',
#     'full_name': '에브리데이 :: 썸띵무드',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/118428997_310168983601048_3070289887402718749_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=TpclU4zgZdMAX-JZRPq&edm=AAo1ks0BAAAA&ccb=7-4&oh=cd2da08b4df74ceb51c81f1679766329&oe=61297DC9&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '17846973431',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '17846973431',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/118428997_310168983601048_3070289887402718749_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=TpclU4zgZdMAX-JZRPq&edm=AAo1ks0BAAAA&ccb=7-4&oh=cd2da08b4df74ceb51c81f1679766329&oe=61297DC9&_nc_sid=01e9e1',
#       'username': 'sum.thing.moooood'}}}},
#   {'node': {'id': '1745484187',
#     'username': 'some0ne2private',
#     'full_name': '👻',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/235465940_4254952567933705_7614679513057967416_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=Bovk46keb5YAX-rplzp&edm=AAo1ks0BAAAA&ccb=7-4&oh=67b35fc6bb768d04b15356f40a5a9485&oe=612A5FF4&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '1745484187',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629639438,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '1745484187',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/235465940_4254952567933705_7614679513057967416_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=Bovk46keb5YAX-rplzp&edm=AAo1ks0BAAAA&ccb=7-4&oh=67b35fc6bb768d04b15356f40a5a9485&oe=612A5FF4&_nc_sid=01e9e1',
#       'username': 'some0ne2private'}}}},
#   {'node': {'id': '39899892698',
#     'username': 'dienv.gib',
#     'full_name': 'd:env',
#     'profile_pic_url': 'https://scontent-cgk1-2.cdninstagram.com/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=scontent-cgk1-2.cdninstagram.com&_nc_ohc=NW2Vr9blyWQAX_UxLKG&edm=AJ0OxeABAAAA&ccb=7-4&oh=c5d17af9f5f682c84f97991b85667bd6&oe=61299C0F&_nc_sid=63a245&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '39899892698',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '39899892698',
#       'profile_pic_url': 'https://scontent-cgk1-2.cdninstagram.com/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=scontent-cgk1-2.cdninstagram.com&_nc_ohc=NW2Vr9blyWQAX_UxLKG&edm=AJ0OxeABAAAA&ccb=7-4&oh=c5d17af9f5f682c84f97991b85667bd6&oe=61299C0F&_nc_sid=63a245&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4',
#       'username': 'dienv.gib'}}}},
#   {'node': {'id': '477038236',
#     'username': 'mxxse0602',
#     'full_name': 'Moose Jan',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/240333711_1681663302222884_7996820110538784999_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=wEd53vNAYkMAX-bUbge&edm=AAo1ks0BAAAA&ccb=7-4&oh=88d9916072423acaa701c4f363948f76&oe=612A95A2&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '477038236',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629680693,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '477038236',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/240333711_1681663302222884_7996820110538784999_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=wEd53vNAYkMAX-bUbge&edm=AAo1ks0BAAAA&ccb=7-4&oh=88d9916072423acaa701c4f363948f76&oe=612A95A2&_nc_sid=01e9e1',
#       'username': 'mxxse0602'}}}},
#   {'node': {'id': '6729978903',
#     'username': '_moaol',
#     'full_name': '모아올',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/119800358_354868989042273_770246469915109902_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=S1dBTgS-BoIAX9dmZxt&edm=AAo1ks0BAAAA&ccb=7-4&oh=7fc92bcd85b96cad244089bfef807b68&oe=612A37C4&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '6729978903',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '6729978903',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/119800358_354868989042273_770246469915109902_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=S1dBTgS-BoIAX9dmZxt&edm=AAo1ks0BAAAA&ccb=7-4&oh=7fc92bcd85b96cad244089bfef807b68&oe=612A37C4&_nc_sid=01e9e1',
#       'username': '_moaol'}}}},
#   {'node': {'id': '6879363249',
#     'username': 'heedong92',
#     'full_name': '한돌이',
#     'profile_pic_url': 'https://scontent-cgk1-2.cdninstagram.com/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=scontent-cgk1-2.cdninstagram.com&_nc_ohc=NW2Vr9blyWQAX_UxLKG&edm=AJ0OxeABAAAA&ccb=7-4&oh=c5d17af9f5f682c84f97991b85667bd6&oe=61299C0F&_nc_sid=63a245&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '6879363249',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '6879363249',
#       'profile_pic_url': 'https://scontent-cgk1-2.cdninstagram.com/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=scontent-cgk1-2.cdninstagram.com&_nc_ohc=NW2Vr9blyWQAX_UxLKG&edm=AJ0OxeABAAAA&ccb=7-4&oh=c5d17af9f5f682c84f97991b85667bd6&oe=61299C0F&_nc_sid=63a245&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4',
#       'username': 'heedong92'}}}},
#   {'node': {'id': '1454824809',
#     'username': 'alyse.xyz',
#     'full_name': '',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/184598264_502578030883414_2246951589685008624_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=mK_PJJVixzIAX9DPZxr&edm=AAo1ks0BAAAA&ccb=7-4&oh=0b6f849094cfc574413814fda34099b7&oe=6129AB82&_nc_sid=01e9e1',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '1454824809',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '1454824809',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/184598264_502578030883414_2246951589685008624_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=mK_PJJVixzIAX9DPZxr&edm=AAo1ks0BAAAA&ccb=7-4&oh=0b6f849094cfc574413814fda34099b7&oe=6129AB82&_nc_sid=01e9e1',
#       'username': 'alyse.xyz'}}}},
#   {'node': {'id': '38893362257',
#     'username': 'loeni____',
#     'full_name': 'LOENI 🌹',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/149268944_196872385461373_3220480957581658990_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=B2pyma1lGE4AX-IRzJI&edm=AAo1ks0BAAAA&ccb=7-4&oh=c28b879252e3ae6ac4280446329b5b13&oe=6129EBE2&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '38893362257',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629636543,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '38893362257',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/149268944_196872385461373_3220480957581658990_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=B2pyma1lGE4AX-IRzJI&edm=AAo1ks0BAAAA&ccb=7-4&oh=c28b879252e3ae6ac4280446329b5b13&oe=6129EBE2&_nc_sid=01e9e1',
#       'username': 'loeni____'}}}},
#   {'node': {'id': '1942822274',
#     'username': 'minseong5478',
#     'full_name': '데일리',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/218204773_423844592037300_698573614101048299_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=cGNtIh_iwj0AX-MRVGG&edm=AAo1ks0BAAAA&ccb=7-4&oh=b6d4a761669e9efff78d53c224093966&oe=6129B069&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '1942822274',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '1942822274',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/218204773_423844592037300_698573614101048299_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=cGNtIh_iwj0AX-MRVGG&edm=AAo1ks0BAAAA&ccb=7-4&oh=b6d4a761669e9efff78d53c224093966&oe=6129B069&_nc_sid=01e9e1',
#       'username': 'minseong5478'}}}},
#   {'node': {'id': '1425415839',
#     'username': 'mirajedi_',
#     'full_name': 'Amirah Z.',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/196807735_935533987300279_7040326988633225903_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=ugZgImYXUSYAX-I1w6t&edm=AAo1ks0BAAAA&ccb=7-4&oh=55c42b46730d61a4914193824da695fe&oe=6129AA82&_nc_sid=01e9e1',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '1425415839',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '1425415839',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/196807735_935533987300279_7040326988633225903_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=ugZgImYXUSYAX-I1w6t&edm=AAo1ks0BAAAA&ccb=7-4&oh=55c42b46730d61a4914193824da695fe&oe=6129AA82&_nc_sid=01e9e1',
#       'username': 'mirajedi_'}}}},
#   {'node': {'id': '24983038183',
#     'username': 'nnnnnnigh_t',
#     'full_name': '밤',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/122023907_714107019182165_8010919300022287907_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=cDtkPfcc6GIAX9Yh15Q&edm=AAo1ks0BAAAA&ccb=7-4&oh=e3f19c4fe0632cb107e6f81c790749b6&oe=61297E13&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '24983038183',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '24983038183',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/122023907_714107019182165_8010919300022287907_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=cDtkPfcc6GIAX9Yh15Q&edm=AAo1ks0BAAAA&ccb=7-4&oh=e3f19c4fe0632cb107e6f81c790749b6&oe=61297E13&_nc_sid=01e9e1',
#       'username': 'nnnnnnigh_t'}}}},
#   {'node': {'id': '41124213858',
#     'username': 'key.__.bum',
#     'full_name': '🦊',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/207621935_476119763487326_3629952250460828073_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=U91OMMg8htwAX-auP6y&edm=AAo1ks0BAAAA&ccb=7-4&oh=ef89a3a8ea78c6e8eeb0e8813cb4af2f&oe=612AC181&_nc_sid=01e9e1',
#     'is_private': True,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '41124213858',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': None,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '41124213858',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/207621935_476119763487326_3629952250460828073_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=U91OMMg8htwAX-auP6y&edm=AAo1ks0BAAAA&ccb=7-4&oh=ef89a3a8ea78c6e8eeb0e8813cb4af2f&oe=612AC181&_nc_sid=01e9e1',
#       'username': 'key.__.bum'}}}},
#   {'node': {'id': '1621945460',
#     'username': 'supertosiri',
#     'full_name': '밤이누나🐈',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/240325194_232615531978410_5154386458632280684_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=r0FmX0JYOm8AX81CFhv&edm=AAo1ks0BAAAA&ccb=7-4&oh=25457002b4047eceb6cc6fd49dc5e1dd&oe=612A6B58&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '1621945460',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 1629629762,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '1621945460',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/240325194_232615531978410_5154386458632280684_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=r0FmX0JYOm8AX81CFhv&edm=AAo1ks0BAAAA&ccb=7-4&oh=25457002b4047eceb6cc6fd49dc5e1dd&oe=612A6B58&_nc_sid=01e9e1',
#       'username': 'supertosiri'}}}},
#   {'node': {'id': '11857402726',
#     'username': 'eeyulll',
#     'full_name': '',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/221863853_839228727017330_2945395349238314648_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=MIg54uUvUzoAX9FKtDT&edm=AAo1ks0BAAAA&ccb=7-4&oh=3a87c5ca00f7e3a974258eb48a864f94&oe=6128F2F0&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '11857402726',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '11857402726',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/221863853_839228727017330_2945395349238314648_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=MIg54uUvUzoAX9FKtDT&edm=AAo1ks0BAAAA&ccb=7-4&oh=3a87c5ca00f7e3a974258eb48a864f94&oe=6128F2F0&_nc_sid=01e9e1',
#       'username': 'eeyulll'}}}},
#   {'node': {'id': '1630963254',
#     'username': 'kiezal.shim',
#     'full_name': 'Kiezal',
#     'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/29096063_178664959426155_6999682779826880512_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=BQRKum_FaNMAX-D28Cv&edm=AAo1ks0BAAAA&ccb=7-4&oh=ff5ea72a0316bb82c4fa75107260ade0&oe=612AAE9D&_nc_sid=01e9e1',
#     'is_private': False,
#     'is_verified': False,
#     'followed_by_viewer': False,
#     'requested_by_viewer': False,
#     'reel': {'id': '1630963254',
#      'expiring_at': 1629770780,
#      'has_pride_media': False,
#      'latest_reel_media': 0,
#      'seen': None,
#      'owner': {'__typename': 'GraphUser',
#       'id': '1630963254',
#       'profile_pic_url': 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/29096063_178664959426155_6999682779826880512_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=BQRKum_FaNMAX-D28Cv&edm=AAo1ks0BAAAA&ccb=7-4&oh=ff5ea72a0316bb82c4fa75107260ade0&oe=612AAE9D&_nc_sid=01e9e1',
#       'username': 'kiezal.shim'}}}}]}

# %%
df5.to_csv('./{}/{}/{}/liked_by_1916953364.csv'.format(keyword,'liked_by','1916953364'), encoding='utf-8-sig')

# %% [markdown]
# ### comments 폴더 조지기

# %%
os.makedirs('./{}/{}/{}'.format(keyword,'comments','1916953364'),exist_ok=True) #하위폴더 생성

# %%
inf_pk = []          #폴더이름
m_id = []            #f_id = []
m_c_owner_id = []    #comm_by_id = []
                     #comm_by_fol = [] #'-'로 채우기
                     #comm_by_real = [] #'-'로 채우기

m_typename = []
m_shortcode = []
m_timestamp = []
m_owner_id = []
m_owner_username = []
m_c_count=[]
m_c_id=[]
m_c_text=[]

m_c_owner_pro_url = []
m_c_owner_username = []
m_c_liked_count = []

# %%
path = 'G:/_2021/kCP/_파이널프로젝트/팀/data/test/comments/1916953364/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.json')] ## 파일명 끝이 .json인 경우

# %%
for i in file_list_py:
    with open(path+i,'r', encoding="utf-8") as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  

    
    comment_count = contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['count']
    for j in range(0,comment_count+1):
        try:
            m_typename.append(contents['graphql']['shortcode_media']['__typename'])
        except:
            m_typename.append('-')
        try:
            m_id.append(contents['graphql']['shortcode_media']['id'])
        except:
            m_id.append('-')
        try:
            m_shortcode.append(contents['graphql']['shortcode_media']['shortcode'])
        except:
            m_shortcode.append('-')
        try:    
            m_timestamp.append(convert_datetime(contents['graphql']['shortcode_media']['taken_at_timestamp']))
        except:
            m_timestamp.append('-')
        try:
            m_owner_id.append(contents['graphql']['shortcode_media']['owner']['id'])
        except:
            m_owner_id.append('-')
        try:
            m_owner_username.append(contents['graphql']['shortcode_media']['owner']['username'])
        except:
            m_owner_username.append('-')
        try:
            m_c_count.append(contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['count'])
        except:
            m_c_count.append('-')
        
        try:
            m_c_id.append(contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][j]['node']['id'])
        except:
            m_c_id.append('-')
        try:
            m_c_text.append(contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][j]['node']['text'])
        except:
            m_c_text.append('-')
        try:
            m_c_owner_id.append(contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][j]['node']['owner']['id'])
        except:
            m_c_owner_id.append('-')
        try:
            m_c_owner_pro_url.append(contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][j]['node']['owner']['profile_pic_url'])
        except:
            m_c_owner_pro_url.append('-')
        try:
            m_c_owner_username.append(contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][j]['node']['owner']['username'])
        except:
            m_c_owner_username.append('-')
        try:
            m_c_liked_count.append(contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][j]['node']['edge_liked_by']['count'])
        except:
            m_c_liked_count.append('-')
    
df4 = pd.DataFrame({"m_typename":m_typename, "m_id":m_id, "m_shortcode":m_shortcode,"m_timestamp":m_timestamp, "m_owner_id":m_owner_id,\
                   "m_owner_username":m_owner_username, "m_c_count":m_c_count, "m_c_id":m_c_id, "m_c_text":m_c_text, "m_c_owner_id":m_c_owner_id,\
                   "m_c_owner_pro_url":m_c_owner_pro_url, "m_c_owner_username":m_c_owner_username, "m_c_liked_count":m_c_liked_count})

df4
# Out:
#      m_typename                 m_id  m_shortcode m_timestamp  m_owner_id  \
# 0    GraphImage  2305287206270595989  B_-BoALAvOV  2020-05-09  1916953364
# 1    GraphImage  2302614039152526469  B_0h0TSg4SF  2020-05-06  1916953364
# 2    GraphImage  2303896102098700919  B_5FUxdAAp3  2020-05-08  1916953364
# 3    GraphImage  2304464819128076819  B_7Gosdg4oT  2020-05-08  1916953364
# 4    GraphImage  2304464819128076819  B_7Gosdg4oT  2020-05-08  1916953364
# ..          ...                  ...          ...         ...         ...
# 618  GraphImage  2616877901066571714  CRRBJYRpI_C  2021-07-13  1916953364
# 619  GraphImage  2616878604921233142  CRRBTnypl72  2021-07-13  1916953364
# 620  GraphImage  2616905435607094491  CRRHaD0JlTb  2021-07-13  1916953364
# 621  GraphImage  2626263349903974564  CRyXJopp2Ck  2021-07-26  1916953364
# 622  GraphImage  2626265713796888789  CRyXsCMprjV  2021-07-26  1916953364
#
#     m_owner_username  m_c_count             m_c_id        m_c_text  \
# 0     dailylook.book          0                  -               -
# 1     dailylook.book          0                  -               -
# 2     dailylook.book          0                  -               -
# 3     dailylook.book          1  17902282927456100  @fruitassembly
# 4     dailylook.book          1                  -               -
# ..               ...        ...                ...             ...
# 618   dailylook.book          0                  -               -
# 619   dailylook.book          0                  -               -
# 620   dailylook.book          0                  -               -
# 621   dailylook.book          0                  -               -
# 622   dailylook.book          0                  -               -
#
#     m_c_owner_id                                  m_c_owner_pro_url  \
# 0              -                                                  -
# 1              -                                                  -
# 2              -                                                  -
# 3     1916953364  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 4              -                                                  -
# ..           ...                                                ...
# 618            -                                                  -
# 619            -                                                  -
# 620            -                                                  -
# 621            -                                                  -
# 622            -                                                  -
#
#     m_c_owner_username m_c_liked_count
# 0                    -               -
# 1                    -               -
# 2                    -               -
# 3       dailylook.book               0
# 4                    -               -
# ..                 ...             ...
# 618                  -               -
# 619                  -               -
# 620                  -               -
# 621                  -               -
# 622                  -               -
#
# [623 rows x 13 columns]

# %%
df4.to_csv('./{}/{}/{}/comments_1916953364.csv'.format(keyword,'comments','1916953364'), encoding='utf-8-sig')

# %%
path1 = 'G:/_2021/kCP/_파이널프로젝트/팀/data/test/comments/1916953364/comments_1916953364_CACkmTYAaiL.json'
with open(path1,'r', encoding="utf-8") as j:
    contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드

# %%
contents['graphql']['shortcode_media']['__typename'] # typename
# Out:
# 'GraphSidecar'

# %%
contents['graphql']['shortcode_media']['id'] #id
# Out:
# '2306566920985487499'

# %%
contents['graphql']['shortcode_media']['shortcode'] #shorcode
# Out:
# 'CACkmTYAaiL'

# %%
contents['graphql']['shortcode_media']['taken_at_timestamp'] #timestamp
# Out:
# 1589184225

# %%
contents['graphql']['shortcode_media']['owner']['id']
contents['graphql']['shortcode_media']['owner']['username']
# Out:
# 'dailylook.book'

# %%
contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['count'] # 댓글수
# Out:
# 1

# %%
contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][0]['node']['id'] #댓글 id
# Out:
# '17948377162339950'

# %%
contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][0]['node']['text'] #댓글 내용
# Out:
# '#윤승아 #여름코디 #여름준비 #모자코디 #daily #패션인스타 #fashion #fashionista #연예인패션 #koreanstyle'

# %%
contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][0]['node']['owner']['id']
contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][0]['node']['owner']['username']
contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][0]['node']['owner']['profile_pic_url']
# Out:
# 'https://scontent-nrt1-1.cdninstagram.com/v/t51.2885-19/s150x150/79753650_1216142538583806_8334228083330514944_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com&_nc_ohc=U8dd4nrfCp0AX9PgHYg&edm=AOMICiUBAAAA&ccb=7-4&oh=4d34e1cbd2bf7dca9eadfaf14aad7d47&oe=612A3217&_nc_sid=124328'

# %%
contents['graphql']['shortcode_media']['edge_media_to_parent_comment']['edges'][0]['node']['edge_liked_by']['count']  #댓글단 계정이 누른 좋아요수
# Out:
# 0

# %% [markdown]
# ### followers 폴더 조지기

# %%
os.makedirs('./{}/{}/{}'.format(keyword,'followers','1916953364'),exist_ok=True) #하위폴더 생성

# %%
# 그 폴더 안에 파일 다 받아오기
path3 = 'E:/2021/KCP/팀원/수집/test/followers/1916953364/'
        #G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/
        #E:/2021/KCP/팀원/수집/test/feed/1916953364/
file_list = os.listdir(path3)
file_list_py = [file for file in file_list if file.endswith('.json')] ## 파일명 끝이 .json인 경우

# %%
inf_pk = [] #폴더이름
fol_pk = []
fol_username = []

#############################필요없음 밑에는(21-08-26)
follower_is_private = []
follower_profile_url = []
follower_has_anonymous_pic=[]

# %%
pd.set_option('display.max_columns', None) ## 모든 열을 출력한다.
pd.set_option('display.max_rows', None) ## 모든 행을 출력한다.

# %%
for i in file_list_py: # 파일이 328개까지 있음
    with open(path3+i,'r', encoding="utf-8") as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
        
    for j in range(0,len(contents['users'])):
        follower_pk.append(contents['users'][j]['pk'])
        follower_username.append(contents['users'][j]['username'])
        follower_is_private.append(contents['users'][j]['is_private'])
        follower_profile_url.append(contents['users'][j]['profile_pic_url'])
        follower_has_anonymous_pic.append(contents['users'][j]['has_anonymous_profile_picture'])

            
df2 = pd.DataFrame({"follower_pk":follower_pk, "follower_username":follower_username, "follower_is_private":follower_is_private,\
                    "follower_profile_url":follower_profile_url, "follower_has_anonymous_pic":follower_has_anonymous_pic})

df2
# Out:
#       follower_pk             follower_username  follower_is_private  \
# 0      1915678657               gggjjjdddaaasss                 True
# 1      5354449259                     ne1110ver                 True
# 2     11881711205                      gongjuny                 True
# 3     49080483632                       hjji_ng                 True
# 4       451572423                     ellie_a.j                False
# 5     18784331677                      jecci__0                 True
# 6     48930308947                     nctjinsim                 True
# 7      7034233865                  gayoungchoi_                 True
# 8      9246721996                    veely___90                 True
# 9      1421417967                      of_hyun_                False
# 10    49034263831                  minyoung7477                False
# 11    44582747835                  sinogyeong45                False
# 12      280701825                      just.ann                False
# 13    48685613932                      na_dapke                False
# 14    49000333073            _the_world_of_nina                False
# 15    40172613224                  saramindaeyo                 True
# 16     6172546719                     kr_kr_eee                 True
# 17    45090460494                     dksrudgh_                False
# 18    14885019431                      totoruho                False
# 19    16731853847                      tomati_o                 True
# 20      401510069                  jangminhyeok                 True
# 21     5385432198                      chlgmlwh                 True
# 22    48522167146                  kei._fashion                 True
# 23    14973474862                 ga_eun__daily                False
# 24    39387497656                    ohokohok_9                 True
# 25     1604317149                       yeeji_2                False
# 26     2958065213                     oh__yeosa                False
# 27    37553524325                      from_k13                False
# 28     1740663488                    my__verse_                 True
# 29     3445400478                      ddonggya                 True
# 30    47118847429                       sayansx                 True
# 31     2378224766                       hhyo_j9                 True
# 32    25561074170                  dongnyeo.521                False
# 33    46982305159                    od_mydaily                False
# 34    47166240683                 lee.shinbi424                 True
# 35    31711785859                    sseoji0526                False
# 36    22932556908                    kkk_326513                 True
# 37    44816839599                    butter7241                 True
# 38    46858405290                      sjyj2273                False
# 39    29051811987                  jinsaimdang1                False
# 40    47305676246                kim_young_bae7                False
# 41     1723324538                      auraa._z                 True
# 42      359319027                     jj.__.eun                 True
# 43     8655026945                    jelly_mon_                 True
# 44    42000974885                    jyu_deng22                 True
# 45    45011373357                   ailish_park                 True
# 46    46937133729                      d__iar_y                 True
# 47    46743631850               happyhappyjoy__                 True
# 48    46903041938                   jiwoooo0417                False
# 49     3679017597                    wonders_eu                 True
# 50     7925065281                   grace_jj_jj                 True
# 51    46756222514                      yulmeee_                False
# 52     8771011781                      kisscocu                False
# 53    35927270589                  ghkd.dls.wns                 True
# 54    35070287294                     4.865.4.9                 True
# 55    22016005084                      ckdiowoo                 True
# 56    46945100368                    okkyeong05                False
# 57     3303709055                    yeinjellin                False
# 58      430233068                      s.nachuu                False
# 59    36788872169                     zuyun.ree                False
# 60     1526701716                     songdmswl                 True
# 61    46168050654                      _ii_oo__                False
# 62      705666515                        seonug                 True
# 63    27376307168                     rrg.__.11                 True
# 64    11878938574                  foxrabbit_dm                 True
# 65    46898003015                  serhimoramos                False
# 66    33488544059                      isfp_ttt                 True
# 67      656388487                      ye1._.8s                 True
# 68    44241468482                     ce.080923                 True
# 69    39855805287                      ksshin20                 True
# 70    18897907844                       csa0404                False
# 71     1212613157                    gyung_hyun                 True
# 72     3273516771                       skmr101                 True
# 73     7417297220                       kja1218                 True
# 74    46742881417                       sl41556                 True
# 75    37631353699                    yaa9502557                False
# 76    44761807551               ho_marcchagalln                 True
# 77     7016285056                  my_own171208                 True
# 78    39069955425                     miao0ooww                 True
# 79       18133014                     jeeasoo14                 True
# 80    24059183028                    pianistiin                False
# 81     6707738843                 minhyun.__.95                False
# 82     1945272473                 jihyeye_hwang                 True
# 83     4791263864                      5th_mira                False
# 84     7218208054                   qawsdxfc123                 True
# 85    45296075149                    sungyeonsi                False
# 86    11321766393                estelle__.__._                False
# 87    45314725798                      mello_wd                 True
# 88     1515273309                    pposong610                 True
# 89     9226422256                  gim_yeeun_07                False
# 90    10982607727                    jaewon_076                False
# 91     2214805124                       henn_23                 True
# 92     9981160612                    binnny_131                 True
# 93     9607517288                     byel_1225                 True
# 94    46290537281                     ooooo.seo                 True
# 95     4177798003                   sarnai_sagu                 True
# 96     8918708033                      eunju517                False
# 97    44674215047                  three_sillia                 True
# 98    35350832730                   yun__s__218                 True
# 99     5410205529                        rt_jhk                False
# 100   36979478407                    clothinguu                 True
# 101    6665745018                 dais______y77                 True
# 102   44782025833                        9dokga                 True
# 103   36602940617                        ziyy_u                 True
# 104   10121936211                   swamppp2018                 True
# 105   22022374251                        5r.rlo                 True
# 106    1427979762                         zzi_n                False
# 107   41196713247              yunhyeonjeong231                False
# 108   45669659145             gimmigyeong532021                 True
# 109       6914365                fullofgracekim                 True
# 110   46725100907                      dooge_un                False
# 111   47096139489                     tmdmsksks                 True
# 112   40520272202                      2sunny.y                 True
# 113    6958962926                      boryjung                 True
# 114   12520708849                   come_true_7                 True
# 115    3041150742                    jsy_851225                 True
# 116   33463148687                        92398l                 True
# 117   41124713760                  n_concerto_f                 True
# 118   44983802668                      wiwiwi_s                False
# 119   32203254332                 ma.ootd_style                 True
# 120   35413399187                      hadduru_                 True
# 121   31470625001                     alskdj.bb                 True
# 122   46851704343                     sang_._.a                 True
# 123   43778483126          a.piece_of_happinezz                 True
# 124   14489559213                      ji_yyyy_                 True
# 125    4148100326                         o8x06                 True
# 126   47284065008                      gggo2103                 True
# 127   37071464403               taljoofairyisme                 True
# 128    4370669017                  heehee_y_119                False
# 129   46261533870                      ronaut__                 True
# 130    1618802536                        qwg_86                 True
# 131    6622873636                     myungju96                False
# 132    8051343988                     toomuchko                 True
# 133   46607370902               shopping_726024                False
# 134    4156307692                       chae_00                 True
# 135   38902566964                    jiang0713j                False
# 136    1504546312                       roseeos                False
# 137   46813612591                  cherry_bb179                 True
# 138    1953739242                     heeyeol85                 True
# 139   45328102435                      _thxxdy9                 True
# 140    5990081267                     bag_hyiae                False
# 141   48689423466                    asdfg.jkl2                 True
# 142   47469251129                     hb_0714_j                False
# 143   49022681586                       moado.m                 True
# 144   48767884017                         six0k                 True
# 145    7596192088                      aiopa345                 True
# 146   44646245729                      j.w0o_12                False
# 147    2131379250            injeonglp_official                False
# 148   45451378224                   sun_glowz4u                False
# 149   48597599584                   jugguekki27                 True
# 150   43452406392               iamgonneloveyou                 True
# 151    5630871662                      rosey621                False
# 152   37701916421                    dais.y0901                 True
# 153   47064198265                      onnveoin                 True
# 154   34467680944                 luv____camper                 True
# 155      39785170                        mhk277                 True
# 156    1587335018                     simtaeng2                False
# 157   32556861454                         qo2_a                 True
# 158   17418686494                  yeon_yuuuuu_                 True
# 159   45037486298                        bscbjs                False
# 160   46570099405                coffee._house_                False
# 161   33555101992                   chaem_jung_                False
# 162   46528312510                     seulyeah0                 True
# 163    3078646254                     bonheur_j                False
# 164    9184630637                       p___w.7                 True
# 165    8929183646                      kim_cw09                False
# 166   40800518831                    didi835757                 True
# 167    5865746204                        daj_b_                 True
# 168     451550687                        yd__l7                False
# 169   44275642326                  kbskkhddb_12                False
# 170    3423503982                      1004lynn                 True
# 171   12115700199                  lovely_sdsd_                 True
# 172    4225931064                     rec.dxxly                 True
# 173   47081817478                   koko_nut_mm                False
# 174   14248043899        megustacantar_y_bailar                 True
# 175   30858189118                    starehrwlf                 True
# 176    7389213627                    sooonuk_94                False
# 177   46867944011                    yeyeye2396                False
# 178   40680599962                     2sang_nee                 True
# 179    2117910189                      tina8786                False
# 180   37232129048                     balimamyu                False
# 181    3662763877                     yeona0823                False
# 182    4654527108                      y.y_0122                False
# 183    3963773371                      gan_zzl_                 True
# 184   46501695379                    1117_l_h_j                 True
# 185     518944657                      sso_0926                False
# 186   46823081642                      olgaeul3                False
# 187   45869036796                        ghsjki                 True
# 188   46862405800                     davi16175                False
# 189    1359213294                     ms2m_ms2m                False
# 190    6962438992                    minsea0220                False
# 191    1565130863                    clickssong                 True
# 192   32167271583                    fonvftujjk                 True
# 193   46870971582                 par_k_juuhyun                 True
# 194   31382133445                    lelele2564                 True
# 195    2200973270                       m.h_yeo                 True
# 196   46880730314                   tjrrndsla01                 True
# 197   34849340039                 fuck_that2021                 True
# 198    1790802803                 kangmyungkook                False
# 199   46511788717                shoppignggngng                 True
# 200    4452547676                       k_1ng_1                 True
# 201    5337648527                       p.rl_ll                 True
# 202    3014571972                      yudaengi                 True
# 203    1651147602            naya_ssofa_kim1234                 True
# 204    2206878447                      iiovob_o                 True
# 205   43995720382                     oseltrwib                 True
# 206   39527809929               mydaily_love_79                 True
# 207    2378721954                      ssd__bss                 True
# 208    1106371788                   culture__aj                 True
# 209    5814570155                       coe_bbo                 True
# 210    7967481830                       hko0814                False
# 211    6798511175                   sumsum01234                 True
# 212    3472423392                   gimyuna4424                 True
# 213     545303911                     drxxxieun                 True
# 214   32006817123                g_an.fragrance                False
# 215     263271641                        kse215                 True
# 216   39170145044                      jyjm0509                False
# 217    7844784091                     haeinhan7                 True
# 218   46159429372                 kim_kang._hee                 True
# 219   44246031227                     comocom.o                False
# 220   35106323176                   lovelyyy__0                 True
# 221   46691938516                      _sonne_y                 True
# 222   21470173910                happybin_agnes                False
# 223   46708744697                      vvhh2474                False
# 224   14100258977                   crazycat129                 True
# 225    3515213668                       bae8018                 True
# 226   46500955742                    coucou0128                False
# 227    4697653648                    seunghannj                False
# 228   46293111397                   dw.ccrusstt                False
# 229    7318057258             _dlfjeksorkalcu__                 True
# 230   44372140498                   yun_oludens                False
# 231   11610469182                    naomi_leow                 True
# 232   40217489308               tildaseuwinteun                False
# 233   39901883804                       euni_i1                 True
# 234   44549480590                    showuntact                False
# 235   46827119168                      miiya_90                 True
# 236   46835617572                      dipochux                False
# 237   32669254754                    imgang_act                 True
# 238   46627687590                      dot_sdot                False
# 239   12870882775                    yumyumsuya                 True
# 240   31133096141                     malkuulry                 True
# 241     959455200                     jminkeung                 True
# 242   43645705392                      bluezi_e                False
# 243   22407008990                       deeel.j                False
# 244   46645159586                      hiju0317                 True
# 245   46862010000                    wljay42728                False
# 246   46833553809                  ninesix_ns96                False
# 247   46697032163                  yimkyung8282                False
# 248    7071221758                hongkyeongyoon                False
# 249   46471263229                      myfashii                False
# 250   30185133144                    taiyanling                False
# 251    9700253991                  me_me__me___                 True
# 252    7327699084                    walceu7121                False
# 253   44361340374                     sjppsh.04                 True
# 254   40123616556                     yandymall                False
# 255   11854566354                  only_just1ce                False
# 256   41111995821                    nature__bb                 True
# 257    2283734266                     soyul55am                False
# 258     372508431                    sua_jo0214                 True
# 259     627946607                       lajinny                 True
# 260   37283878899                       molyyuu                 True
# 261    9305882955                 cohone_amy._j                False
# 262    2036826717                      inorihnn                 True
# 263    9258104631                      hyk7960a                False
# 264    9486352564                 nailist_salon                False
# 265   27628849012                        1.27rm                False
# 266    7437704022                      sinna_2e                False
# 267    4184389952                     im_jinhyo                 True
# 268   45807220895                      bori2031                False
# 269   47130387453                    kimkj_0712                False
# 270    1379395313                   cherie.kwon                False
# 271   41642866729                      xeeosxee                 True
# 272   31711247539                  pleasantly_0                 True
# 273    9159634415                    gustnr4fkd                False
# 274   48288130502                    seumurrnet                False
# 275   33637529659                     shairoiro                False
# 276   48156288757                 hjh_love_2012                False
# 277   48683654290                      oopss792                False
# 278   48064185663               awesome_jiwon87                False
# 279   45401265295                      wonnote_                False
# 280   21917528702                   thisisxinbi                False
# 281   25290583738                  delphinus210                 True
# 282   45386165615                      itsoonme                 True
# 283   46344809725                        wldo._                 True
# 284   46605585618                      n_lab_02                False
# 285    1700144725                     ddd__yuri                 True
# 286   19755818418               hwanghyeonjin95                False
# 287   11122341770                 snfgl__qpdlql                 True
# 288    2039356192                      cybb0226                 True
# 289   46120417402                     ilgi_.hyo                 True
# 290    4794767154                    hello_eyre                False
# 291    4663430798                   bunnytable1                False
# 292    6851352123                       som_0.3                False
# 293    1410597680                       ha_8.18                False
# 294   46261019106             eclairerhomme__01                 True
# 295   46801758118                fashion_sunjin                False
# 296    2157502892               popcornunicorn_                 True
# 297    7279210631                coeseonhyi9625                False
# 298   42803200181                       iopl904                 True
# 299   41634235221                       5ji.lee                 True
# 300    1165531529                    godchaerim                False
# 301    4057648697                  yaya67807251                False
# 302   46242271189                 wondersarahxx                 True
# 303    1273853006                     _k._mong_                 True
# 304   45090597379           fashion_style_luver                 True
# 305   41144248148                     s20000222                 True
# 306    1061733074                       hae.ree                 True
# 307    9193786016                    youi.chung                False
# 308   28186900705                    monaco2108                False
# 309   29570688272                   diet_vingle                False
# 310   46638602885                   witty_jerry                 True
# 311   46570920536               fruitringcereal                False
# 312    2284444970          nothing_special_but0                False
# 313    7936108853                   ye._.eun_05                False
# 314   46364471510                     seong6126                 True
# 315    6252609987                     mishu2017                 True
# 316    6162766943                 ramen__killer                False
# 317    8137523023                   nulll_nulli                 True
# 318   46083948879                        023r24                 True
# 319   16469150446                       leesdve                 True
# 320     637947698                      choizihe                False
# 321   46629883733                fashion._.0102                 True
# 322    6532163343                   hyeonyyy_23                False
# 323   40817864411                    pung000501                False
# 324    8448153308                 _hyeonju_0413                False
# 325   45483694381                   sihoho.0987                False
# 326   39679273933                 sosohan.girok                 True
# 327     609579798                  ann_inawhile                 True
# 328   35946658220                    mmnmmnmmnz                 True
# 329    3557338873                  ssonjeongmin                 True
# 330   46830032168                   f_haebokchi                False
# 331    6814608714                   non_lozical                 True
# 332    2976383046                    soruru8577                False
# 333   14718542091                         o12zh                 True
# 334   44951721323                    jjinbbaang                 True
# 335   31028593890                  dkssu_gktpdy                 True
# 336    4186277837                       gee_vvv                 True
# 337    2285317513                    ju_velylll                False
# 338   20253402126                    ye_bin_33_                False
# 339   45368601733                 kang.mamalove                 True
# 340    8653162496               minjeong2ya_o3o                False
# 341   14642476027                      xd_nnnnn                 True
# 342   46260732073                      kim90_33                False
# 343    8414770046                   dkanrjskgid                False
# 344   41014896947                       do.0718                False
# 345    2025012260                      hy_0116_                False
# 346    8531059335                 yumigyeong989                 True
# 347   43375061545                     spur.mood                False
# 348   44887215750                    iiii._.000                False
# 349    1565505046                        haexny                False
# 350    9049044818                 minjisecretee                 True
# 351   46220167401                   yyefjygkdfk                False
# 352   16357759153                        hij__o                 True
# 353    6855333484                  _______j.eun                False
# 354    5509393495         americanblue_official                False
# 355   45696559851             naebugaejungeyaha                 True
# 356    1359251979                        dkdiel                 True
# 357     661960610                  chae.0.co.kr                 True
# 358   44894274034                      ooodapil                 True
# 359    1477052844               http_ddakgu_com                False
# 360    1354202889                     eun_hye_2                False
# 361   44019327309               sseoisseoisseoi                False
# 362   44855430231                cheese_esssses                 True
# 363   46274192110                    park___015                False
# 364    1423055468                    m_____in99                 True
# 365    7561017122                 amorfati___20                 True
# 366   32693834855                 plants_heesun                False
# 367   39676319663      _ilikeburgerhowaboutyou_                 True
# 368   10437155860                   elimseseehc                 True
# 369    1000896502                    ___eeeeeun                 True
# 370    9634552131                  lnvertedribs                False
# 371   45287820694                     ohbanzzak                False
# 372    5979864602                      koko__co                 True
# 373    7395787978                        hj_onw                 True
# 374   39644767532              offlimits__wmall                False
# 375    9368584393                     a_vcssesa                 True
# 376   16930452490                  rmklipandeye                 True
# 377   40892322838                    lo____ng_0                 True
# 378   45690453701                my_dnuorgyalp_                 True
# 379    5350169465                  jiyeon_bgmom                 True
# 380   45853067952               pixie._.hayoon_                 True
# 381   10617675377                   ___geurumom                False
# 382   28351628047                       rieidir                 True
# 383   41819049957            monarmoire_chaerim                False
# 384   37318693295                 dbdbdipppp___                 True
# 385    5367665081                 jogyeongo1022                False
# 386    1651956630                  kkang_cho_co                 True
# 387    2535128400                      830307sh                 True
# 388   46234178275                   younggenkum                 True
# 389     509787648                        bluek0                 True
# 390     973465530                   jiminiyam17                 True
# 391    5949909907                    jshair0221                False
# 392    7441796125                      toldjahh                 True
# 393   38907525025                    lucy191229                 True
# 394    8024532190                      hmhs0707                False
# 395   49201009341                      n.jjoo_d                 True
# 396    4631452364                   judy_smpark                False
# 397       3262256                     moongong_                False
# 398   42405435322                     ddori0618                 True
# 399   48098933236           21wonderful_feeling                False
# 400   38492636485                         h2qoa                 True
# 401    2313111412                    2ndcoco_sy                False
# 402   42180892035                      dndj1524                 True
# 403    3504130386                     wlals0126                 True
# 404   30963614044                       ear__ae                False
# 405   12158475395                      naeun05n                False
# 406    9491201058                        fm71.8                False
# 407    6257908662                     sung.hak_                False
# 408   39250236711                      jihuya_7                 True
# 409    4518448880                    e_______eh                 True
# 410     627526898                       ttohye_                False
# 411    8563869453                       sumier2                 True
# 412     992812301                        _anooy                False
# 413    1823646156                    every_huii                 True
# 414   13750989953                    sanghee810                 True
# 415     641076913                    mansourr.r                 True
# 416   17800629160                     esox_eoeo                 True
# 417    8597893783                 camper_junmom                False
# 418    3993781116                    mluxynov29                False
# 419    1932652738                      luvsomam                False
# 420    1295968527                    kkkkkareum                 True
# 421   46194593830                      jeggunam                False
# 422    2983285547                       ohio_ha                 True
# 423   33248075297                      cmos_kim                False
# 424    1518084137                     augyuzzzz                 True
# 425     316915755                  yj.rachelkim                 True
# 426    8108133477                   kimminji120                 True
# 427     459746286                      haha_ahh                 True
# 428    1925105828                     oops.2002                 True
# 429   45985787473                       grain_3                False
# 430   45273044053                        bo_e22                False
# 431   44804357916                     vst._.123                 True
# 432   43200805883                      jina_jz_                False
# 433    5752851839              gongjeongeun6353                 True
# 434    2221650086                      hideshd1                False
# 435    4169591913                  ninano____88                 True
# 436   45503067555                  znejiddoospw                 True
# 437    1154962354              nurulainiwahab88                False
# 438   46383154557                     finenuts_                 True
# 439   27987931348                     misug5703                False
# 440   18177756728                  parksangmi72                False
# 441   44336779976                     cov_erupp                 True
# 442   45010120546                    youn201217                False
# 443   31770452466                      jeju.gio                False
# 444   13872668778                       vvqpli_                 True
# 445    8977119046                  carrrrrry.on                 True
# 446   42288864449                     yexin_oeh                False
# 447    3022121539                      cawhy_ok                False
# 448   43147449317                    luna.hyeya                False
# 449    1374637869                      soo_8519                False
# 450    3253034640                     yeon_yony                 True
# 451   13871092249                      jeveeee_                 True
# 452    1409082159                  tkrhkskan226                False
# 453   12412410912                     nuyhiseel                False
# 454    1540947092                     k.sunny__                 True
# 455   46366860551                      meidyopp                 True
# 456   39495796688                      _0701am_                 True
# 457   46338160365                      xnzlcbxn                False
# 458    5522255120                      tue2_lip                 True
# 459   27925061960                    fav.bucket                 True
# 460   44501661423                    lux_runway                False
# 461    3781915807                o__hyeonjin__o                 True
# 462   10478996222                    jjjjsyyyoo                 True
# 463   38725030249                      dneisnaz                 True
# 464   46051992680                 crawl_forward                 True
# 465   46572496291                  fashionisooo                 True
# 466   31780691722               yummy___yojeong                 True
# 467   44433282534                       oua1211                False
# 468    1588995059                       jhs0717                 True
# 469    1779343212                     kimsemida                 True
# 470   30189765449                 kangjistory85                 True
# 471    7927942890             dali_charlie_vert                False
# 472    5808953905                       oyn0719                 True
# 473    8302837203               h.me_planteri.r                 True
# 474   45503257496                 thddlleedream                 True
# 475    4214236479                      alsdk121                False
# 476    7400343551               liana6_lookbook                False
# 477   45746411177                   so_so_jihye                False
# 478   26953779046                     merryluvz                 True
# 479   45851635000                     daedae167                 True
# 480   43218751042                  ggull_chocho                 True
# 481    6776223024                 soulfood50100                 True
# 482    1531073173                      yeonzin_                 True
# 483    2213603225                zsilverrrrrrrr                 True
# 484   46209584907                     2022a_bcd                False
# 485   13583514962                     xoxo_bobe                 True
# 486   21271274849                    __latte000                False
# 487    3240865878                 simhyewon9022                 True
# 488   29915662212               worldclass_me95                False
# 489   46000868204                   sjsjciidj92                 True
# 490    1687993568                   inyoung_min                 True
# 491   29569697072                  wisewiseblue                False
# 492   42133547324                  a01026299136                False
# 493   38553460068                       fxzxzyy                 True
# 494   15962377999                 seohyiweon950                False
# 495    3082141945                       pyun_s1                 True
# 496   31699122296                   subin_k0717                 True
# 497   46159830534                        do10ss                 True
# 498    8504369419                     mmm970314                 True
# 499    7267875996                bagsoyeong3789                False
# 500    3079719568                       g_pan97                 True
# 501   46331234170                      seodh900                 True
# 502   36874741458                      gotj2109                 True
# 503    1496822080                       purggy_                False
# 504    2618085285               bbyangyoon_0511                False
# 505   45157313660                      heyy__ym                 True
# 506     264178082                     7148200_s                 True
# 507    2087673588                   dg_ti_mi_ta                 True
# 508   18040128706                      gos.0107                False
# 509   41782181772                    milli12135                 True
# 510   44981578140                 pipi.kitekite                False
# 511   28956927195                    suhyun7462                 True
# 512   40989942469                        oooupk                 True
# 513   32181839254                       weei_o1                 True
# 514   34247246408                 miniminichick                 True
# 515    5999787070                        ehrn15                False
# 516    2262531480                      _shadms_                 True
# 517   35316834245                    dandorop_i                 True
# 518   46147996788                      napa2685                False
# 519   40031009043                  lithe_wonnie                False
# 520    1718293853                      go_yumi_                False
# 521   44884917008                     lee__9520                 True
# 522   45553680547                olleh_22347827                False
# 523   31504265009                 marigold_0605                False
# 524    5887424894                   drawing1975                False
# 525    1676891415                        jj_kku                 True
# 526   48755519019                  honggeumnim1                False
# 527   43860895414                    co_nte___t                 True
# 528   48675878399                      wiwioody                 True
# 529   47361772482                     iii_sy112                False
# 530     665936536                     kimyoni__                False
# 531   31862988985                worldclassssss                 True
# 532    2192400515                      yeomi_95                False
# 533   48668820364                     jjj_95_as                 True
# 534   16385847756                     s_min__07                False
# 535   43278235320                      savio_rr                 True
# 536   45605840764                     eunsu_tea                 True
# 537   13049232143                    46.7862418                False
# 538   46001153075                      ahsp2075                 True
# 539    2360324229                iyeonjeong7821                False
# 540   45989275945                  happy_090318                False
# 541    3974705967                eunsook_lovely                 True
# 542    1589470197                hayeong._.0209                False
# 543   45777678234                       30362.8                 True
# 544   45193665126                   jj____jenny                 True
# 545   45745904043                    lovesh0215                False
# 546   45972349946              fashion_my_lover                False
# 547    1461648009                       cjy6617                False
# 548   44736234776             sunoo_enhypen1130                False
# 549    1798510378                     2eekyung_                False
# 550   46148677655                       na.bb.y                 True
# 551    6881124139                      aapppccc                 True
# 552   46004993631                    eundy_8024                 True
# 553    1514985923              alexavillalbuena                 True
# 554     752152050                      alicemih                False
# 555   46156308527                  petr_ichor77                False
# 556    3097617574                   daisy_lim04                 True
# 557    3447722210                      ahnthaii                False
# 558     783021362                  babpuri_unni                False
# 559    4922465419                    araara_kkk                False
# 560   45790965830                       iwy_sum                 True
# 561   10595314984                       y__onon                False
# 562   35180414890                       mvssifs                 True
# 563    7715839996                       9z9z_il                 True
# 564   21251357424                       kyim555                 True
# 565   34021920995                     play_ovo_                 True
# 566    3232599760                 mim_mim_heeit                False
# 567   44591304952                      yuu__.or                 True
# 568   36634023569                     hyneyy_ly                 True
# 569   35313259997                 jungyoungju48                False
# 570    8227309430                    euler2.717                 True
# 571    9518002350                      haans_38                 True
# 572   42865645993                     primera_q                 True
# 573    3635212373                   jinwon._.01                False
# 574    2982927374                        ma8won                 True
# 575    5964897387                   _seo.yoon__                False
# 576     577557545                        eix_mf                 True
# 577   11145258772                  amugggggguna                 True
# 578   13800637818              reality_of_grace                 True
# 579    5461309782                    heesun_bae                False
# 580   45944191197               bangtan_natgnab                 True
# 581   35522094187                      kkkamjja                False
# 582    5683236312                 kimyunhui2720                 True
# 583    1472717005                     _hyojin_p                 True
# 584   14322048548                         9503x                False
# 585   22405624922                     tnale3460                 True
# 586   13772449398                     islocked_                 True
# 587    4223860262                     on_lee912                 True
# 588    3668713798                   fffirsthong                 True
# 589   45944454488                       19_19_p                False
# 590   25518062093                      ksjcidna                 True
# 591    6147370774                    dldmdrud88                False
# 592   10358904532                   greenshape_                 True
# 593   31352841299                       poiut_3                 True
# 594   27394750197                _luv_myself_33                 True
# 595   44834534390                       ymjun30                False
# 596    3522054345                     yeyewooon                 True
# 597    3074199978                   sejeong3695                False
# 598   13761176129                     kamtono77                False
# 599    2188163410                      bbangk_a                False
# 600   45472503699                       pol_ws1                 True
# 601    3186984710                    mini._.zii                False
# 602   41317861258                       moaalss                False
# 603    5635663310                hanna_kim_0707                 True
# 604   44993260814                   eun_tae1026                False
# 605   15960770540                        hhnz__                False
# 606   37254245907                      whbedusw                 True
# 607    7162828359                       yo3owon                False
# 608    2302142480                   jinju091502                False
# 609    6978682999                     today_nle                 True
# 610   45956178891                       qbin885                 True
# 611    2020129652                  alsrud__0413                False
# 612    8930095403                    jesly_jane                False
# 613    1533904990                       x02x23x                False
# 614    2801293489                evelyn_kim1984                False
# 615    6968201273                   jongseo2412                False
# 616    1271518463                    shinji.hye                False
# 617    2035661678                    bbongsunny                False
# 618   21930651713                      llly7n__                 True
# 619    4565730421                    sunnyday3_                False
# 620   41530603149                 iridescent_2_                 True
# 621    1773209953                       hansj35                False
# 622   42816746334                      vwv_1324                 True
# 623    5406044421                      nrol2004                False
# 624    9647125630                       orm2810                False
# 625   44291925425                 prettynan0320                False
# 626   36079236272                    ssung88123                False
# 627   45500050070                seong_hyeon_23                 True
# 628    9878654386                    mingyu8_31                False
# 629    3069716162                       railtoh                False
# 630    1681976473                       1zi6xll                 True
# 631   46108659688                 nam_mi_kyeong                False
# 632     312468008                     kyeon9a_8                 True
# 633   10232544665                   jiyeon_b126                False
# 634   43868618592                   space_kim__                False
# 635       3302082                  _christinabk                 True
# 636    7943273151                 mingyung_0106                 True
# 637      50904220                   keunyoung27                 True
# 638    5265166042                  bingbong.oor                 True
# 639   21378750980                   deargirl_st                 True
# 640   45572134308                     ekwnrdug_                False
# 641   45560890877                  lepetitflot_                False
# 642   45894522026                     tten_geum                 True
# 643   45045802364                 white_.turtle                 True
# 644    1710944016                      __miin.j                False
# 645   31331486555                    dhdnjfdldy                 True
# 646    9205805323                     03._.0730                 True
# 647   45215504487                   9ming______                 True
# 648     611418102                     doyeony_k                False
# 649   45731546185                     ksung1812                False
# 650    3757636581                    aveda_anns                False
# 651   30879909746                     thirunary                 True
# 652   35053215901                      za_c_030                 True
# 653    3877048591                  atpttr_gmlwn                 True
# 654   45684833601                     68920187_                 True
# 655     365529514                   aflower____                False
# 656   45069962499                    minjicoe59                False
# 657    4049746157                       yoomj76                False
# 658    2064742894                        ye.jn2                 True
# 659   48887192920             only_fashion_funk                 True
# 660   48892160678                      iam_2514                 True
# 661    5423176185                 guulie_daikan                 True
# 662     491057828                        n.jjoo                False
# 663   37365653772                   kimhyohan54                False
# 664    2983045078                      hmju_224                 True
# ...
# 3599                        True
# 3600                       False
# 3601                        True
# 3602                       False
# 3603                       False
# 3604                       False
# 3605                       False
# 3606                       False
# 3607                       False
# 3608                       False
# 3609                       False
# 3610                        True
# 3611                       False
# 3612                        True
# 3613                        True
# 3614                       False
# 3615                        True
# 3616                       False
# 3617                       False
# 3618                        True
# 3619                       False
# 3620                       False
# 3621                       False
# 3622                       False
# 3623                        True
# 3624                       False
# 3625                       False
# 3626                       False
# 3627                       False
# 3628                       False
# 3629                        True
# 3630                        True
# 3631                       False
# 3632                       False
# 3633                       False
# 3634                        True
# 3635                        True
# 3636                        True
# 3637                       False
# 3638                        True
# 3639                       False
# 3640                       False
# 3641                        True
# 3642                        True
# 3643                       False
# 3644                       False
# 3645                        True
# 3646                        True
# 3647                       False
# 3648                        True
# 3649                        True
# 3650                       False
# 3651                        True
# 3652                        True
# 3653                        True
# 3654                       False
# 3655                        True
# 3656                       False
# 3657                        True
# 3658                        True
# 3659                       False
# 3660                       False
# 3661                       False
# 3662                       False
# 3663                        True
# 3664                        True
# 3665                       False
# 3666                        True
# 3667                       False
# 3668                        True
# 3669                        True
# 3670                        True
# 3671                        True
# 3672                       False
# 3673                        True
# 3674                        True
# 3675                       False
# 3676                       False
# 3677                       False
# 3678                       False
# 3679                       False
# 3680                        True
# 3681                       False
# 3682                       False
# 3683                       False
# 3684                       False
# 3685                       False
# 3686                       False
# 3687                       False
# 3688                        True
# 3689                        True
# 3690                        True
# 3691                       False
# 3692                        True
# 3693                        True
# 3694                       False
# 3695                       False
# 3696                       False
# 3697                        True
# 3698                        True
# 3699                       False
# 3700                       False
# 3701                       False
# 3702                       False
# 3703                        True
# 3704                        True
# 3705                        True
# 3706                        True
# 3707                        True
# 3708                       False
# 3709                       False
# 3710                       False
# 3711                        True
# 3712                       False
# 3713                        True
# 3714                       False
# 3715                       False
# 3716                       False
# 3717                        True
# 3718                        True
# 3719                       False
# 3720                       False
# 3721                       False
# 3722                        True
# 3723                        True
# 3724                       False
# 3725                       False
# 3726                       False
# 3727                        True
# 3728                       False
# 3729                       False
# 3730                       False
# 3731                       False
# 3732                       False
# 3733                       False
# 3734                        True
# 3735                       False
# 3736                       False
# 3737                        True
# 3738                       False
# 3739                       False
# 3740                        True
# 3741                        True
# 3742                        True
# 3743                       False
# 3744                        True
# 3745                       False
# 3746                       False
# 3747                       False
# 3748                        True
# 3749                       False
# 3750                       False
# 3751                       False
# 3752                       False
# 3753                       False
# 3754                        True
# 3755                        True
# 3756                       False
# 3757                        True
# 3758                       False
# 3759                       False
# 3760                       False
# 3761                       False
# 3762                       False
# 3763                       False
# 3764                       False
# 3765                        True
# 3766                       False
# 3767                       False
# 3768                       False
# 3769                        True
# 3770                       False
# 3771                       False
# 3772                       False
# 3773                       False
# 3774                       False
# 3775                       False
# 3776                        True
# 3777                       False
# 3778                        True
# 3779                        True
# 3780                        True
# 3781                        True
# 3782                       False
# 3783                       False
# 3784                       False
# 3785                       False
# 3786                       False
# 3787                        True
# 3788                       False
# 3789                       False
# 3790                       False
# 3791                       False
# 3792                       False
# 3793                       False
# 3794                        True
# 3795                       False
# 3796                       False
# 3797                       False
# 3798                        True
# 3799                        True
# 3800                        True
# 3801                        True
# 3802                        True
# 3803                        True
# 3804                       False
# 3805                       False
# 3806                        True
# 3807                        True
# 3808                       False
# 3809                       False
# 3810                       False
# 3811                       False
# 3812                       False
# 3813                       False
# 3814                       False
# 3815                        True
# 3816                        True
# 3817                        True
# 3818                       False
# 3819                       False
# 3820                        True
# 3821                        True
# 3822                       False
# 3823                       False
# 3824                       False
# 3825                       False
# 3826                       False
# 3827                        True
# 3828                       False
# 3829                       False
# 3830                        True
# 3831                        True
# 3832                       False
# 3833                       False
# 3834                       False
# 3835                       False
# 3836                       False
# 3837                       False
# 3838                       False
# 3839                        True
# 3840                       False
# 3841                       False
# 3842                        True
# 3843                       False
# 3844                        True
# 3845                       False
# 3846                        True
# 3847                       False
# 3848                        True
# 3849                        True
# 3850                       False
# 3851                       False
# 3852                       False
# 3853                       False
# 3854                       False
# 3855                        True
# 3856                        True
# 3857                       False
# 3858                        True
# 3859                       False
# 3860                        True
# 3861                        True
# 3862                       False
# 3863                        True
# 3864                       False
# 3865                        True
# 3866                       False
# 3867                       False
# 3868                       False
# 3869                       False
# 3870                        True
# 3871                        True
# 3872                       False
# 3873                       False
# 3874                       False
# 3875                       False
# 3876                        True
# 3877                        True
# 3878                       False
# 3879                        True
# 3880                       False
# 3881                       False
# 3882                       False
# 3883                       False
# 3884                        True
# 3885                        True
# 3886                       False
# 3887                       False
# 3888                       False
# 3889                        True
# 3890                       False
# 3891                       False
# 3892                       False
# 3893                       False
# 3894                       False
# 3895                       False
# 3896                       False
# 3897                       False
# 3898                        True
# 3899                       False
# 3900                        True
# 3901                       False
# 3902                        True
# 3903                       False
# 3904                        True
# 3905                       False
# 3906                        True
# 3907                       False
# 3908                        True
# 3909                       False
# 3910                       False
# 3911                       False
# 3912                       False
# 3913                        True
# 3914                        True
# 3915                       False
# 3916                       False
# 3917                       False
# 3918                       False
# 3919                       False
# 3920                        True
# 3921                       False
# 3922                       False
# 3923                       False
# 3924                       False
# 3925                       False
# 3926                       False
# 3927                       False
# 3928                       False
# 3929                       False
# 3930                       False
# 3931                       False
# 3932                        True
# 3933                       False
# 3934                       False
# 3935                       False
# 3936                       False
# 3937                        True
# 3938                       False
# 3939                        True
# 3940                       False
# 3941                        True
# 3942                       False
# 3943                       False
# 3944                       False
# 3945                       False
# 3946                       False
# 3947                        True
# 3948                        True
# 3949                       False
# 3950                       False
# 3951                       False
# 3952                       False
# 3953                        True
# 3954                       False
# 3955                       False
# 3956                       False
# 3957                       False
# 3958                        True
# 3959                       False
# 3960                       False
# 3961                       False
# 3962                       False
# 3963                        True
# 3964                       False
# 3965                       False
# 3966                       False
# 3967                       False
# 3968                       False
# 3969                       False
# 3970                       False
# 3971                        True
# 3972                        True
# 3973                       False
# 3974                       False
# 3975                       False
# 3976                        True
# 3977                       False
# 3978                       False
# 3979                        True
# 3980                       False
# 3981                       False
# 3982                        True
# 3983                       False
# 3984                       False
# 3985                       False
# 3986                       False
# 3987                        True
# 3988                        True
# 3989                       False
# 3990                       False
# 3991                       False
# 3992                        True
# 3993                        True
# 3994                        True
# 3995                       False
# 3996                        True
# 3997                       False
# 3998                        True
# 3999                        True
# 4000                       False
# 4001                        True
# 4002                       False
# 4003                        True
# 4004                       False
# 4005                       False
# 4006                        True
# 4007                       False
# 4008                       False
# 4009                        True
# 4010                       False
# 4011                       False
# 4012                       False
# 4013                        True
# 4014                        True
# 4015                       False
# 4016                       False
# 4017                       False
# 4018                       False
# 4019                       False
# 4020                       False
# 4021                       False
# 4022                        True
# 4023                        True
# 4024                       False
# 4025                        True
# 4026                       False
# 4027                        True
# 4028                        True
# 4029                       False
# 4030                        True
# 4031                       False
# 4032                        True
# 4033                       False
# 4034                        True
# 4035                        True
# 4036                       False
# 4037                        True
# 4038                       False
# 4039                        True
# 4040                        True
# 4041                        True
# 4042                       False
# 4043                       False
# 4044                        True
# 4045                        True
# 4046                       False
# 4047                       False
# 4048                       False
# 4049                       False
# 4050                       False
# 4051                       False
# 4052                       False
# 4053                       False
# 4054                       False
# 4055                       False

# %%
df2.to_csv('./{}/{}/{}/followers_1916953364.csv'.format(keyword,'followers','1916953364'), encoding='utf-8-sig')

# %%
json_file_path = "G:/_2021/kCP/_파이널프로젝트/팀/data/test/followers/1916953364/followers_1916953364_" + str(5) + ".json"
with open(json_file_path,'r', encoding="utf-8") as j:
    contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드

# %%
contents['users'][10]['pk'] #pk
# Out:
# 25699851325

# %%
contents['users'][0]['username']
# Out:
# 'l0ve5304'

# %%
contents['users'][0]['is_private']
# Out:
# False

# %%
contents['users'][0]['profile_pic_url']
# Out:
# 'https://instagram.fixc2-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fixc2-1.fna.fbcdn.net&_nc_ohc=NW2Vr9blyWQAX87l-a_&edm=AEsR1pMBAAAA&ccb=7-4&oh=c390eb8649791aa0935610ddad7a8f8e&oe=61299C0F&_nc_sid=3f45ac&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4'

# %%
contents['users'][0]['has_anonymous_profile_picture']
# Out:
# True

# %%
# Out:
# 11

# %% [markdown]
# ### following 폴더 조지기

# %%
os.makedirs('./{}/{}/{}'.format(keyword,'following','1916953364'),exist_ok=True) #하위폴더 생성

# %%
# 그 폴더 안에 파일 다 받아오기
path4 = 'E:/2021/KCP/팀원/수집/test/following/1916953364/'
        #G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/
        #E:/2021/KCP/팀원/수집/test/feed/1916953364/
file_list = os.listdir(path4)
file_list_py = [file for file in file_list if file.endswith('.json')] ## 파일명 끝이 .json인 경우

# %%
inf_pk = [] #폴더이름
fol_pk = []
fol_username = []


##필요없음
following_is_private = []
following_profile_url = []
following_has_anonymous_pic=[]

# %%
for i in file_list_py: # 파일이 328개까지 있음
    with open(path4+i,'r', encoding="utf-8") as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
        
    for j in range(0,len(contents['users'])):
        following_pk.append(contents['users'][j]['pk'])
        following_username.append(contents['users'][j]['username'])
        following_is_private.append(contents['users'][j]['is_private'])
        following_profile_url.append(contents['users'][j]['profile_pic_url'])
        following_has_anonymous_pic.append(contents['users'][j]['has_anonymous_profile_picture'])

            
df3 = pd.DataFrame({"following_pk":following_pk, "following_username":following_username, "following_is_private":following_is_private,\
                    "following_profile_url":following_profile_url, "following_has_anonymous_pic":following_has_anonymous_pic})

df3
# Out:
#     following_pk      following_username  following_is_private  \
# 0     5625350535                 keykney                 False
# 1     1371968417  werenotreallystrangers                 False
# 2      315710838                  therow                 False
# 3     7140177628          jennierubyjane                 False
# 4     2519184304                   rouje                 False
# 5      230524891            moonguiyoung                 False
# 6      409044943        montanafurniture                 False
# 7     1583606539          hosfeltgallery                 False
# 8      489174325           thearmoryshow                 False
# 9     6325656694     inspiredbyallthings                 False
# 10     350372154                   lrnce                 False
# 11   11927703766        pearly_interiors                 False
# 12   16210986194             escapecadet                 False
# 13    5666276207              aviersechs                 False
# 14      16500742              fakerstrom                 False
# 15       5395721    barbarakristoffersen                 False
# 16     298052003              annaastrup                 False
# 17    2061360342              filis_pina                 False
# 18   10199067225           thelevelstore                 False
# 19    7526924505                _sentaku                 False
# 20     310091532                jeff_bou                 False
# 21    2180459738           sandrarossi03                 False
# 22    2206452324          mathildemaxine                 False
# 23     200479423         thestylesponge_                 False
# 24    2276279149                bear.ltd                 False
# 25     499441996               eudonchoi                 False
# 26      10136939             neadadeters                 False
# 27     194906421               marvaldel                 False
# 28     365467658       shotfromthestreet                 False
# 29      52703512               brunabear                 False
# 30       3902309              oliviafaeh                 False
# 31     207160552               haydesign                 False
# 32      11973107         studionicholson                 False
# 33     227713814          saramedinalind                 False
# 34      29439378             lisadengler                 False
# 35     188873330              oliviakijo                 False
# 36       1824710        brittanybathgate                 False
# 37     237967268                vanhalam                 False
# 38     302510512             laquinonero                 False
# 39      13952309               jwhorner_                 False
# 40     392125511               cosstores                 False
#
#                                 following_profile_url  \
# 0   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 1   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 2   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 3   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 4   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 5   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 6   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 7   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 8   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 9   https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 10  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 11  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 12  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 13  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 14  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 15  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 16  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 17  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 18  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 19  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 20  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 21  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 22  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 23  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 24  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 25  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 26  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 27  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 28  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 29  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 30  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 31  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 32  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 33  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 34  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 35  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 36  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 37  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 38  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 39  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 40  https://scontent-ssn1-1.cdninstagram.com/v/t51...
#
#     following_has_anonymous_pic
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# 5                         False
# 6                         False
# 7                         False
# 8                         False
# 9                         False
# 10                        False
# 11                        False
# 12                        False
# 13                        False
# 14                        False
# 15                        False
# 16                        False
# 17                        False
# 18                        False
# 19                        False
# 20                        False
# 21                        False
# 22                        False
# 23                        False
# 24                        False
# 25                        False
# 26                        False
# 27                        False
# 28                        False
# 29                        False
# 30                        False
# 31                        False
# 32                        False
# 33                        False
# 34                        False
# 35                        False
# 36                        False
# 37                        False
# 38                        False
# 39                        False
# 40                        False

# %%
df3.to_csv('./{}/{}/{}/following_1916953364.csv'.format(keyword,'following','1916953364'), encoding='utf-8-sig')

# %%
json_file_path = "G:/_2021/kCP/_파이널프로젝트/팀/data/test/following/1916953364/following_1916953364_" + str(1) + ".json"
with open(json_file_path,'r', encoding="utf-8") as j:
    contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드

# %%
contents['users'][0]['profile_pic_url']
# Out:
# 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-19/s150x150/66334204_2478490795719916_4152281906831949824_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_ohc=59uJ3RA_EZcAX9DP-N3&edm=ALB854YBAAAA&ccb=7-4&oh=0ca98907d995be29a5dc4e58210b46b2&oe=612999E3&_nc_sid=04cb80'

# %%
contents['users'][0]['has_anonymous_profile_picture']
# Out:
# False

# %%
contents['users'][0]['is_private']
# Out:
# False

# %%
len(contents['users'])
# Out:
# 12

# %% [markdown]
# ### feed 폴더 조지기

# %%
os.makedirs('./{}/{}'.format(keyword,'feed'),exist_ok=True) #하위폴더 생성

# %%
os.makedirs('./{}/{}/{}'.format(keyword,'feed','1916953364'),exist_ok=True) #하위폴더 생성

# %%
inf_pk = [] #폴더 이름
f_id = [] # 고유id
f_shortcode = [] # feed 고유 shortcode
f_typename = [] #게시글 타입 네임
#피드 리스트 csv  

#피드 상세정보 csv 두개 나눠서 만들기
inf_pk = []
feed_id = []            f_id = [] # 고유id # 고유id
feed_timestamp = []     timestamp = [] # #게시글 업로드 시간
                        f_diff_time = [] #'-'로 채우기 
feed_comment_count = [] comm_count = [] #댓글수
feed_liked = []         liked_count = []  #좋아요 수
feed_text = []          f_text #사용자가 입력한 text
feed_caption = []       f_caption #a ccessibility caption
is_partnership = []     is_partnership #광고게시글 여부



#밑에꺼는 필요없음
feed_thumbnail = []     f_thumbnail #피드 썸네일 url
feed_tagged_username = [] #태그계정명
feed_tagged_profile_url = [] #태그계정 프로필url
feed_tagged_id = [] #태그계정 id

feed_owner_id = [] # 게시글작성자 고유id
feed_owner_username = [] #게시글 작성자 username

# %%
for i in range(1,45): #1~44
    json_file_path = "G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/feed_1916953364_" + str(i) + ".json"
                    #G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/
                    #E:/2021/KCP/팀원/수집/test/feed/1916953364/
    with open(json_file_path,'r', encoding="utf-8") as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
    
        
    
    tagged_len = len(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_tagged_user']['edges'])
    for j in range(0,tagged_len): #태그계정 개수만큼
#         feed_typename.append('-')
#         feed_typename.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['__typename'])
# #         feed_id.append('-')
#         feed_id.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['id'])

    
        try:
            feed_typename.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['__typename'])
        except:
            feed_typename.append('-')
        try:
            feed_id.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['id'])
        except:
            feed_id.append('-')

        try:
            feed_caption.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['accessibility_caption'])
        except:
            feed_caption.append('-')
        try:
            feed_text.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_caption']['edges'][0]['node']['text'])
        except:
            feed_text.append('-')
        try:
            feed_shortcode.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['shortcode'])
        except:
            feed_shortcode.append('-')
        try:
            feed_comment_count.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_comment']['count'])
        except:
            feed_comment_count.append('-')
        try:
            is_paired_partnership.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['is_paid_partnership'])
        except:
            is_paired_partnership.append('-')
        try:
            feed_timestamp.append(convert_datetime(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['taken_at_timestamp']))
        except:
            feed_timestamp.append('-')
        try:
            feed_liked.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_preview_like']['count'])
        except:
            feed_liked.append('-')
        try:
            feed_owner_id.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['owner']['id'])
        except:
            feed_owner_id.append('-')
        try:
            feed_owner_username.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['owner']['username'])
        except:
            feed_owner_username.append('-')
        try:
            feed_thumbnail.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['thumbnail_src'])
        except:
            feed_thumbnail.append('-')
        
        
        feed_tagged_username.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_tagged_user']['edges'][j]['node']['user']['username'])

        feed_tagged_profile_url.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_tagged_user']['edges'][j]['node']['user']['profile_pic_url'])

        feed_tagged_id.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_tagged_user']['edges'][j]['node']['user']['id'])

        
#         try:
#             feed_caption.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['accessibility_caption'])
#         except:
#             feed_caption.append('-')
#         try:
#             feed_text.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_caption']['edges'][0]['node']['text'])
#         except:
#             feed_text.append('-')
# #       except:feed_shortcode.append('-')
#         feed_shortcode.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['shortcode'])
# #         feed_comment_count.append('-')
#         feed_comment_count.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_comment']['count'])
# #         is_paired_partnership.append('-')
#         is_paired_partnership.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['is_paid_partnership'])
# #         feed_timestamp.append('-')
#         feed_timestamp.append(convert_datetime(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['taken_at_timestamp']))
# #         feed_liked.append('-')
#         feed_liked.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_preview_like']['count'])
# #         feed_owner_id.append('-')
#         feed_owner_id.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['owner']['id'])
# #         feed_owner_username.append('-')
#         feed_owner_username.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['owner']['username'])
# #         feed_thumbnail.append('-')
#         feed_thumbnail.append(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['thumbnail_src'])

#     feed_tagged_username.append('-')
#     feed_tagged_profile_url.append('-')
#     feed_tagged_id.append('-')
    
    

print(len(feed_typename), len(feed_id), len(feed_tagged_username), len(feed_tagged_profile_url), len(feed_tagged_id),\
      len(feed_caption), len(feed_text), len(feed_shortcode), len(feed_comment_count), len(is_paired_partnership), len(feed_timestamp),\
      len(feed_liked), len(feed_owner_id), len(feed_owner_username), len(feed_thumbnail))
        
df2 = pd.DataFrame({"feed_typename":feed_typename, "feed_id":feed_id, "feed_tagged_username":feed_tagged_username,\
                    "feed_tagged_profile_url":feed_tagged_profile_url, "feed_tagged_id":feed_tagged_id, "feed_caption":feed_caption,\
                    "feed_text":feed_text,"feed_shortcode":feed_shortcode,"feed_comment_count":feed_comment_count,\
                    "is_paired_partnership":is_paired_partnership,"feed_timestamp":feed_timestamp, "feed_liked":feed_liked,\
                    "feed_owner_id":feed_owner_id, "feed_owner_username":feed_owner_username, "feed_thumbnail":feed_thumbnail})

df2
# Out:
# 44 44 44 44 44 44 44 44 44 44 44 44 44 44 44
#    feed_typename              feed_id   feed_tagged_username  \
# 0     GraphImage  2626970216535860122        andotherstories
# 1     GraphImage  2608966934265845709      withyoon.official
# 2     GraphImage  2592287928464360947             urbanic_30
# 3     GraphImage  2592287928464360947              abkn_shop
# 4     GraphImage  2576259593607067283         recto_official
# 5     GraphImage  2558115167487783086                  _olnl
# 6     GraphImage  2540745875003899345       addmore.official
# 7     GraphImage  2526305889852642782              jooberry_
# 8     GraphImage  2518313078859616006               rina_t2m
# 9   GraphSidecar  2505282065992517468        mirabelle.seoul
# 10    GraphImage  2492981989995945140             lerubiscph
# 11    GraphImage  2492981989995945140           sofia.citron
# 12    GraphImage  2477781010493113132              andbeige_
# 13    GraphImage  2468999683157325438             luv.minuet
# 14    GraphImage  2458866773133797906            luckyssong_
# 15    GraphImage  2445910648029616666        ronanbouroullec
# 16    GraphImage  2436398260511214742             purehajung
# 17    GraphImage  2429848995766621973       partysu_official
# 18    GraphImage  2423392283861779785             purehajung
# 19    GraphImage  2415409313351762421             solenelara
# 20    GraphImage  2408851257398728145          itsnajmaahmed
# 21    GraphImage  2403806436485353036           _alittlebeat
# 22    GraphImage  2397961169554946169               doveneon
# 23    GraphImage  2393694141088464482                2nnue__
# 24    GraphImage  2388540008047913644            jillburro_w
# 25    GraphImage  2384904320563860788            taramilktea
# 26    GraphImage  2379818832391925572           joiedevivier
# 27    GraphImage  2374799232910682447                commesi
# 28    GraphImage  2369778176370035264                linenne
# 29    GraphImage  2366839887329725580                choijjo
# 30    GraphImage  2361782761888592120                  gucci
# 31    GraphImage  2361782761888592120            lovecodyou_
# 32    GraphImage  2358143961266198769               threecut
# 33    GraphImage  2354532111891028451           freckleseoul
# 34    GraphImage  2350162484675177491    funfromfun_official
# 35    GraphImage  2343721902528456603             luv.minuet
# 36    GraphImage  2339371365410507227               pit.apat
# 37    GraphImage  2337083294681763294              yunboram_
# 38    GraphImage  2325675945966670253                ejiyang
# 39    GraphVideo  2317535870057568326  tulipmania.experience
# 40  GraphSidecar  2315456822200336158             newbalance
# 41  GraphSidecar  2315456822200336158                 ezysun
# 42    GraphImage  2311803180746486625               la__room
# 43    GraphImage  2306800374184579351              ribbonbit
#
#                               feed_tagged_profile_url feed_tagged_id  \
# 0   https://scontent-ssn1-1.cdninstagram.com/v/t51...       29949727
# 1   https://scontent-ssn1-1.cdninstagram.com/v/t51...     1925326280
# 2   https://scontent-ssn1-1.cdninstagram.com/v/t51...     3037299275
# 3   https://scontent-ssn1-1.cdninstagram.com/v/t51...    21248707716
# 4   https://scontent-ssn1-1.cdninstagram.com/v/t51...     1510861157
# 5   https://scontent-ssn1-1.cdninstagram.com/v/t51...      348256236
# 6   https://scontent-ssn1-1.cdninstagram.com/v/t51...    19839432980
# 7   https://scontent-ssn1-1.cdninstagram.com/v/t51...      348654181
# 8   https://scontent-ssn1-1.cdninstagram.com/v/t51...     1535511209
# 9   https://scontent-ssn1-1.cdninstagram.com/v/t51...     8008363343
# 10  https://scontent-ssn1-1.cdninstagram.com/v/t51...    11806031364
# 11  https://scontent-ssn1-1.cdninstagram.com/v/t51...    29582496363
# 12  https://scontent-ssn1-1.cdninstagram.com/v/t51...      567719725
# 13  https://scontent-ssn1-1.cdninstagram.com/v/t51...      454565301
# 14  https://scontent-ssn1-1.cdninstagram.com/v/t51...      174009115
# 15  https://scontent-ssn1-1.cdninstagram.com/v/t51...      241953423
# 16  https://scontent-ssn1-1.cdninstagram.com/v/t51...      479871373
# 17  https://scontent-ssn1-1.cdninstagram.com/v/t51...     2701855505
# 18  https://scontent-ssn1-1.cdninstagram.com/v/t51...      479871373
# 19  https://scontent-ssn1-1.cdninstagram.com/v/t51...      288706908
# 20  https://scontent-ssn1-1.cdninstagram.com/v/t51...      202555359
# 21  https://scontent-ssn1-1.cdninstagram.com/v/t51...     8478870259
# 22  https://scontent-ssn1-1.cdninstagram.com/v/t51...    35573508395
# 23  https://scontent-ssn1-1.cdninstagram.com/v/t51...     6926865849
# 24  https://scontent-ssn1-1.cdninstagram.com/v/t51...      173863741
# 25  https://scontent-ssn1-1.cdninstagram.com/v/t51...       25453231
# 26  https://scontent-ssn1-1.cdninstagram.com/v/t51...     1452240404
# 27  https://scontent-ssn1-1.cdninstagram.com/v/t51...     8335077868
# 28  https://scontent-ssn1-1.cdninstagram.com/v/t51...      582058764
# 29  https://scontent-ssn1-1.cdninstagram.com/v/t51...      390588783
# 30  https://scontent-ssn1-1.cdninstagram.com/v/t51...        2421050
# 31  https://scontent-ssn1-1.cdninstagram.com/v/t51...     5572792394
# 32  https://scontent-ssn1-1.cdninstagram.com/v/t51...     2283116842
# 33  https://scontent-ssn1-1.cdninstagram.com/v/t51...      661205761
# 34  https://scontent-ssn1-1.cdninstagram.com/v/t51...     1515346111
# 35  https://scontent-ssn1-1.cdninstagram.com/v/t51...      454565301
# 36  https://scontent-ssn1-1.cdninstagram.com/v/t51...     1503684550
# 37  https://scontent-ssn1-1.cdninstagram.com/v/t51...      423446287
# 38  https://scontent-ssn1-1.cdninstagram.com/v/t51...      542174888
# 39  https://scontent-ssn1-1.cdninstagram.com/v/t51...    29371093963
# 40  https://scontent-ssn1-1.cdninstagram.com/v/t51...      204654945
# 41  https://scontent-ssn1-1.cdninstagram.com/v/t51...       21660511
# 42  https://scontent-ssn1-1.cdninstagram.com/v/t51...     1479105567
# 43  https://scontent-ssn1-1.cdninstagram.com/v/t51...      333628840
#
#    feed_caption     feed_text feed_shortcode  feed_comment_count  \
# 0          None  아래 위 다 예쁘댭,,    CR0335gJqOa                   0
# 1          None         편해보이는    CQ06ZqTp9fN                   0
# 2          None             -    CP5qCLrpsXz                   0
# 3          None             -    CP5qCLrpsXz                   0
# 4          None         귀요미가방    CPAtnNmJDaT                   0
# 5          None             -    COAQDD8pfCu                   0
# 6          None             -    CNCiulwJX3R                   1
# 7          None             -    CMPPdJmpNXe                   3
# 8          None             -    CLy2GcSpc8G                   0
# 9          None           뽀인뜨    CLEjMP1pAdc                   1
# 10         None             -    CKY2elZJ5y0                   0
# 11         None             -    CKY2elZJ5y0                   0
# 12         None             -    CJi2LOBpoMs                   0
# 13         None             -    CJDpiFpJPZ-                   0
# 14         None          조거팬츠    CIfpk1ypqoS                   0
# 15         None             -    CHxnsaAJpoa                   0
# 16         None             -    CHP008xJoyW                   0
# 17         None             -    CG4jsmqglcV                   0
# 18         None             -    CGhnnFHAQVJ                   0
# 19         None             -    CGFQfkdgIH1                   0
# 20         None             -    CFt9XS6ARXR                   0
# 21         None             -    CFcCTfTgc5M                   0
# 22         None             💌    CFHRPqQgLh5                   0
# 23         None             -    CE4HCOUgv5i                   0
# 24         None             -    CElzHt3gSqs                   0
# 25         None            귀욥    CEY4dgCgNU0                   0
# 26         None             -    CEG0J6GgW9E                   0
# 27         None             -    CD0-1HygulP                   0
# 28         None             -    CDjJLIfAkpA                   0
# 29         None             -    CDYtFZkg4yM                   0
# 30         None             -    CDGvOifArD4                   0
# 31         None             -    CDGvOifArD4                   0
# 32         None             -    CC5z3BUgRjx                   0
# 33         None             -    CCs-nsdg9nj                   0
# 34         None             -    CCddFP_g2wT                   0
# 35         None       핏 예쁜 셔츠    CCGkqccgueb                   0
# 36         None         비오는 날    CB3HdzBA4nb                   0
# 37         None       연두색 스커트    CBu_N_GAY3e                   0
# 38         None      베이지 롱스커트    CBGdfNuA5Gt                   0
# 39            -       🌷🌷🌷🌷🌷🌷🌷    CApiphRAdhG                   0
# 40         None             -    CAiJ7ZEAX8e                   0
# 41         None             -    CAiJ7ZEAX8e                   0
# 42         None         여름 니트    CAVLL6TAzNh                   0
# 43         None      비오는날 트렌치    CADZrfnApEX                   0
#
#     is_paired_partnership feed_timestamp  feed_liked feed_owner_id  \
# 0                   False     2021-07-27          26    1916953364
# 1                   False     2021-07-02          26    1916953364
# 2                   False     2021-06-09          29    1916953364
# 3                   False     2021-06-09          29    1916953364
# 4                   False     2021-05-18          23    1916953364
# 5                   False     2021-04-23          24    1916953364
# 6                   False     2021-03-30          20    1916953364
# 7                   False     2021-03-10          24    1916953364
# 8                   False     2021-02-27          26    1916953364
# 9                   False     2021-02-09          38    1916953364
# 10                  False     2021-01-23          32    1916953364
# 11                  False     2021-01-23          32    1916953364
# 12                  False     2021-01-02          20    1916953364
# 13                  False     2020-12-21          19    1916953364
# 14                  False     2020-12-07          37    1916953364
# 15                  False     2020-11-19          21    1916953364
# 16                  False     2020-11-06          22    1916953364
# 17                  False     2020-10-28          17    1916953364
# 18                  False     2020-10-19          29    1916953364
# 19                  False     2020-10-08          35    1916953364
# 20                  False     2020-09-29          20    1916953364
# 21                  False     2020-09-22          20    1916953364
# 22                  False     2020-09-14          24    1916953364
# 23                  False     2020-09-08          19    1916953364
# 24                  False     2020-09-01          11    1916953364
# 25                  False     2020-08-27          16    1916953364
# 26                  False     2020-08-20          11    1916953364
# 27                  False     2020-08-13           7    1916953364
# 28                  False     2020-08-06           6    1916953364
# 29                  False     2020-08-02           3    1916953364
# 30                  False     2020-07-26           6    1916953364
# 31                  False     2020-07-26           6    1916953364
# 32                  False     2020-07-21          14    1916953364
# 33                  False     2020-07-16          10    1916953364
# 34                  False     2020-07-10           5    1916953364
# 35                  False     2020-07-01           8    1916953364
# 36                  False     2020-06-25           9    1916953364
# 37                  False     2020-06-22          10    1916953364
# 38                  False     2020-06-07           2    1916953364
# 39                  False     2020-05-26           3    1916953364
# 40                  False     2020-05-23           4    1916953364
# 41                  False     2020-05-23           4    1916953364
# 42                  False     2020-05-18           3    1916953364
# 43                  False     2020-05-12           7    1916953364
#
#    feed_owner_username                                     feed_thumbnail
# 0       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 1       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 2       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 3       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 4       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 5       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 6       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 7       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 8       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 9       dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 10      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 11      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 12      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 13      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 14      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 15      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 16      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 17      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 18      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 19      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 20      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 21      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 22      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 23      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 24      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 25      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 26      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 27      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 28      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 29      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 30      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 31      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 32      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 33      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 34      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 35      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 36      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 37      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 38      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 39      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 40      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 41      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 42      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...
# 43      dailylook.book  https://scontent-ssn1-1.cdninstagram.com/v/t51...

# %%
df2.to_csv('./{}/{}/{}/feed_1916953364.csv'.format(keyword,'feed','1916953364'), encoding='utf-8-sig')

# %%
json_file_path = "G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/feed_1916953364_" + '3' + ".json"
                #G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/
                #E:/2021/KCP/팀원/수집/test/feed/1916953364/
with open(json_file_path,'r', encoding="utf-8") as j:
    contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드

# %%
contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['__typename']
# Out:
# 'GraphImage'

# %%
contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['id']
# Out:
# '2626970216535860122'

# %%
contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['accessibility_caption']

# %%
contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_caption']['edges'][0]['node']
# Out:
# {'text': '아래 위 다 예쁘댭,,'}

# %%
contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['thumbnail_src']
# Out:
# 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c0.135.1080.1080a/s640x640/224103567_891092924625113_5019575729842423277_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=105&_nc_ohc=FPy_o43pkaQAX9wrf95&edm=APU89FABAAAA&ccb=7-4&oh=95b7c069c324df3727601c0821f68a7c&oe=6129FCE3&_nc_sid=86f79a'

# %%
convert_datetime(contents['data']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['taken_at_timestamp'])
# Out:
# '2021-07-27'

# %% [markdown]
# ### profile 폴더 조지기

# %%
os.makedirs('./{}/profile'.format(keyword),exist_ok=True) #하위폴더 생성

# %%
json_file_path="G:/_2021/kCP/_파이널프로젝트/팀/data/test/profile/profile___look_it__.json" # 파일로드 (파일명 : NY.GDP.MKTP.CD.json )

# %%
files = ['profile___look_it__','profile_0.218kg','profile_aespastyle','profile_bang_outfit','profile_banshoi','profile_brandi__official','profile_bsha_bsha',\
        'profile_cane_bros','profile_canyon.pictures','profile_coolguy9283','profile_crushj_yeon','profile_daily_liny_98','profile_dailyfashion_news','profile_dailylook.book',\
        'profile_dangmihyi2','profile_ddins_official','profile_elecom_korea','profile_fashion_9woori_s','profile_fashion_theqoo','profile_fashionandstyle.official',\
        'profile_fashionista_styling_','profile_final_scene','profile_fingersuit_kr','profile_fuckit9982','profile_hyesuk.go','profile_insight.co.kr_fashion',\
        'profile_irenebaefashion','profile_joysstyles_','profile_jungan_u','profile_jungwoostyles','profile_juniac1118','profile_k_fashion_looks','profile_knock_the',\
        'profile_lake_magazine','profile_leeboyoungstyle','profile_mianmian_bebe','profile_muto2148','profile_myeongjaunni','profile_nobling_official1','profile_passion5_official',\
        'profile_photoly7','profile_pictorial.sensio','profile_placesimulation','profile_seulgistyles_','profile_shinseunghun_','profile_shoe_prize','profile_soulssa',\
        'profile_style.editor_34p','profile_style_88_','profile_style_mans','profile_styleby.ohmygirl','profile_styleby.redvelvet','profile_suabaragi','profile_vintage_bbadda',\
        'profile_yerikimstyle']

# %%
inf_id = []                               #inf_pk
biography = []                            #bio
edge_followed_by = []                     #fol_count
edge_follow = []                          #folwing_count
v_media_count = [] + i_media_count = []   #feed_count = []
business_category_name = []               #bus_cat_name = []
category_enum = []                        #cat_enum = []
                                          #inf_sex #연산 필요
                                          #inf_age #연산 필요
profile_pic_url = []                      #pic_url
                                          #real_fol_count  #진짜 팔로워수

    
###밑에꺼는 필요없음
username = []


is_business_account = []
is_professional_account = []


category_name = []
is_private = []

# %%
df = pd.DataFrame(index=range(0,0))#, columns=['index'])

for i in range(0,len(files)):
    json_file_path = "G:/_2021/kCP/_파이널프로젝트/팀/data/test/profile/" + files[i] + ".json"
                    #G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/
                    #E:/2021/KCP/팀원/수집/test/feed/1916953364/
    with open(json_file_path,'r', encoding="utf-8") as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
#     temp = pd.DataFrame(contents['graphql']['user'])
#     tempdf = temp.loc[['count'], ['biography', 'edge_followed_by', 'edge_follow','id', 'is_business_account', 'is_professional_account'\
#                           ,'business_category_name', 'category_enum', 'category_name', 'is_private', 'profile_pic_url', 'username']]
    inf_id.append(contents['graphql']['user']['id'])
    username.append(contents['graphql']['user']['username'])
    biography.append(contents['graphql']['user']['biography'])
    edge_followed_by.append(contents['graphql']['user']['edge_followed_by']['count'])
    edge_follow.append(contents['graphql']['user']['edge_follow']['count'])
    is_business_account.append(contents['graphql']['user']['is_business_account'])
    is_professional_account.append(contents['graphql']['user']['is_professional_account'])
    business_category_name.append(contents['graphql']['user']['business_category_name'])
    category_enum.append(contents['graphql']['user']['category_enum'])
    category_name.append(contents['graphql']['user']['business_category_name'])
    is_private.append(contents['graphql']['user']['is_private'])
    v_media_count.append(contents['graphql']['user']['edge_felix_video_timeline']['count'])
    i_media_count.append(contents['graphql']['user']['edge_owner_to_timeline_media']['count'])
    profile_pic_url.append(contents['graphql']['user']['profile_pic_url'])
    
df1 = pd.DataFrame({"inf_id":inf_id, "username":username, "biography":biography, "edge_followed_by":edge_followed_by, \
                       "edge_follow":edge_follow, "is_business_account":is_business_account, "is_professional_account":is_professional_account,\
                       "business_category_name":business_category_name, "category_enum":category_enum, "category_name":category_name,\
                       "v_media_count":v_media_count, "i_media_count":i_media_count,"is_private":is_private, "profile_pic_url":profile_pic_url})
    
df1
# Out:
#          inf_id                  username  \
# 0    8005180162               __look_it__
# 1    5566945015                   0.218kg
# 2   45906937921                aespastyle
# 3   40961995563               bang_outfit
# 4   48962855780                   banshoi
# 5    2218550660          brandi__official
# 6    1394688376                 bsha_bsha
# 7    1563788188                 cane_bros
# 8   42934449545           canyon.pictures
# 9    1297647769               coolguy9283
# 10   1651957095               crushj_yeon
# 11  46088894392             daily_liny_98
# 12  38980901318         dailyfashion_news
# 13   1916953364            dailylook.book
# 14  46526656287                dangmihyi2
# 15    866947432            ddins_official
# 16   4057123831              elecom_korea
# 17  44377137381          fashion_9woori_s
# 18   3865979785            fashion_theqoo
# 19   3500614932  fashionandstyle.official
# 20   2016264755      fashionista_styling_
# 21  26039066648               final_scene
# 22  48077165346             fingersuit_kr
# 23   4752827967                fuckit9982
# 24   1374816594                 hyesuk.go
# 25   2494123960     insight.co.kr_fashion
# 26  35641698457           irenebaefashion
# 27  30316172873               joysstyles_
# 28  24401827886                  jungan_u
# 29  35803666192             jungwoostyles
# 30   3885671730                juniac1118
# 31  22566228417           k_fashion_looks
# 32    614515131                 knock_the
# 33  48646162911             lake_magazine
# 34  20225518661           leeboyoungstyle
# 35   4639396333             mianmian_bebe
# 36   6704185900                  muto2148
# 37   2103025565              myeongjaunni
# 38   5010150517         nobling_official1
# 39   2296309794         passion5_official
# 40   5870333100                  photoly7
# 41   3411103232          pictorial.sensio
# 42   2227621116           placesimulation
# 43  15202623986             seulgistyles_
# 44    435680883             shinseunghun_
# 45  13284579121                shoe_prize
# 46   1019962414                   soulssa
# 47   1505962480          style.editor_34p
# 48   1996261596                 style_88_
# 49   2043464728                style_mans
# 50  44756465001          styleby.ohmygirl
# 51  38769156492         styleby.redvelvet
# 52   1580807589                 suabaragi
# 53   7489768030            vintage_bbadda
# 54  29325677496              yerikimstyle
#
#                                             biography  edge_followed_by  \
# 0   [ 당신만을 위한 데일리룩 ]\n-\n-\n-\nLook It\n#데일리룩 #남자패...              1195
# 1   ✍.📸.🔪.🍣.🦖\nChef.Writer.Photographer.graphic de...             11058
# 2   fashion n looks for aespa💄\n- price convert to...             14940
# 3   _sᴇᴏᴜʟ, ᴋᴏʀᴇᴀ 🇰🇷\n_ғᴏʟʟᴏᴡ, ᴄᴏɴᴛᴀᴄᴋ - ᴅᴍ ✉️\n_ᴍ...              5707
# 4        사업자 인증완료 #1:1쇼핑몰 #원하시는 스타일이 있다면 부담없이 문의주세용❤️                21
# 5                  마침내 옷도 하루배송 시대📦\n지금 주문하면 이미도착❗️\n-            106145
# 6                                                                 16774
# 7   카네브로스 2020결산 특별 세일기회전 시작했습니다 매주 바뀌는 상품구성을 구경해보세요!             14475
# 8   🎥Videographer Park JunHyung\n T.010.8615.6765 ...               359
# 9   1.브랜드 아우내 순대 END\n2.브랜드 와플칸 END\n3.브랜드 츄러스1500...             16431
# 10                                                                32160
# 11       🌸데일리룩🌸\n🌸패션계정🌸\n🌸DM 👉🏻 Inquiry🌸\n성균관대 의상학과👗👖               199
# 12  👻 패션 커뮤니티 🎤제보 받아요😇🙏🏻\n데일리로 패션 뉴스 요약 해주는 언니 🙋🏻‍...             17422
# 13        내일 뭐입지 고민때문에 만든 Fashion 계정\n💜 매일 업로드하려 노력 중              4059
# 14  ←﻿본계정 문의:   @gilhaerang\n←재택근무 모집(재태크)#좋아요\n←부...               275
# 15                   @eng2nism \n이쪽으로 팔로워 해주세요😭 계정옮겨요              5267
# 16  #가성비 #디자인 #펀펀 한 당신을 위해👏\n인친님들이 즐겁게 사용하는 모습을 담겠...              1652
# 17  네이버웹툰 ‘아홉수 우리들’ 의 패션 업로드✨\n[fan account] 내가 좋아...               165
# 18  Korea No.1 fashion instagram \nㆍ패션에 관심 많은 더쿠👀\...             71584
# 19  패션 & 라이프스타일 디지털 미디어.\nFashion & Lifestyle Digi...            539853
# 20                                          셀럽들의 패션 팁              6180
# 21  All Styling by @rons.tyle \n🔹Creative things /...              4493
# 22  Tag us Event #핑거수트 #fingersuit #셀프네일 @fingersu...              6495
# 23                                                                 2539
# 24  건강하고 멋진 life style 😎\n30대에  멋진 워라벨을 꿈꾸는 1인💋\n먹...              4981
# 25          📧 비즈니스 문의 DM / 메일 : ad_team@insight.co.kr            260997
# 26  • fashion source of singer, actress, host & mo...             16893
# 27  fashion source of joy @_imyour_joy ✨\n🤍 for pa...             24692
# 28           Jung An Ryu\n아날로그 라이프\n빈티지 러버♡\n79. 옛날사람               281
# 29           for @ncit_kimjw from NCT\nkinda ia sorry              8438
# 30                                   패션을 사랑하는 사람in 나!              3346
# 31  💃🏻 20-30대 여성들의 패션 미디어 콘텐츠\n👜 스타가 착용한 가방정보 : @k...             19737
# 32  ⠀\n⠀\n@_unframe\n@villa_de_109\n@knockknock_of...             14575
# 33  ⠀\n[ 코디 소개 📂 ]  [ 아이템 리뷰 🔍]\n[ 패션 정보 🗞 ]  [ 스타...               251
# 34                                                                 1190
# 35                                                                 1009
# 36  .\n☆☆ 상품 구매방법 ☆☆\n카카오톡/ 카카오스토리 아이디 ▶ muto2148 ...              1314
# 37                    명품과 패션을 자잘하게 아는 언니💖\n질샌더 가방 추천👇              1031
# 38  💍핸드메이드 패션쥬얼리 쇼핑몰\n⠀⠀⠀⠀\n💎14K/18K 다이아몬드&원석 쥬얼리 ...              8566
# 39  매일 아침 100여명의 장인들이 만들어가는\n「열정을 담는 공간」\nCafeㅣBak...             12285
# 40  에세이  '망원경을 가지고 싶어한 아이' 저자\n메리츠 화재 2021캘린더 사진작가...              3507
# 41                             화보나 관심사 사진!!\n기타 잡스타그램               374
# 42  패션 디자인 유학 포트폴리오 PLACE(플레이스)\n#CSM #RCA #LCF #P...              3885
# 43  fashion source of @hi_sseulgi 💛🌼\nnot imperson...             29885
# 44       Handsome corp.\n#한섬 #VMD #패션 #데일리 #라이프스타일\n-              5362
# 45  👟 스니커즈 | @shoe_prize\n🎁 킥스 | @kickskicks_offic...            150273
# 46  📣Soulssa schedule\n▶ 8/19 #아르지닌 OPEN\n▶ 8/22 #...            127357
# 47                               프로필링크 누르고 베스트상품 보기^^              1468
# 48                                                                16329
# 49                               style mans magazin 😎             28024
# 50  🔎stylebyomg_ (member / brand)\n- please give c...              3824
# 51  💗💛💙💚💜\nCREDIT IF TAKING INFO\n🔎 #sbrv_brand\n🔎...             32847
# 52                                    Game programmer              2343
# 53  👉🏻남녀공용 유니섹스 프리미엄 빈티지샵  \n👉🏻두개이상 구매 손ᄂ...              5554
# 54  [REST]\nFor Red Velvet's Yeri @yerimiese 💜\nCo...              4899
#
#     edge_follow  is_business_account  is_professional_account  \
# 0           823                 True                     True
# 1          1920                 True                     True
# 2           140                False                     True
# 3          2464                 True                     True
# 4           214                False                    False
# 5             5                 True                     True
# 6           493                 True                     True
# 7          5979                 True                     True
# 8           354                 True                     True
# 9           349                 True                     True
# 10         3941                 True                     True
# 11          115                False                     True
# 12          377                 True                     True
# 13           41                False                     True
# 14         3460                False                    False
# 15            3                 True                     True
# 16         1250                 True                     True
# 17            2                False                    False
# 18          381                False                    False
# 19            0                 True                     True
# 20         4780                False                    False
# 21           99                 True                     True
# 22            2                 True                     True
# 23         1772                False                    False
# 24         2676                False                    False
# 25          249                 True                     True
# 26          177                False                     True
# 27           71                 True                     True
# 28           52                 True                     True
# 29           53                 True                     True
# 30         6154                 True                     True
# 31            1                 True                     True
# 32         4937                 True                     True
# 33            0                 True                     True
# 34            0                False                    False
# 35         2512                 True                     True
# 36         5206                 True                     True
# 37          364                False                     True
# 38         2092                 True                     True
# 39           87                 True                     True
# 40         3189                 True                     True
# 41          324                False                    False
# 42           56                 True                     True
# 43          157                False                     True
# 44         2809                 True                     True
# 45            2                 True                     True
# 46         1672                False                     True
# 47           54                 True                     True
# 48         6001                False                    False
# 49         5241                False                    False
# 50          598                False                     True
# 51          453                 True                     True
# 52          797                False                    False
# 53         3132                 True                     True
# 54           21                 True                     True
#
#                          business_category_name          category_enum  \
# 0   Personal Goods & General Merchandise Stores               CLOTHING
# 1                        Creators & Celebrities                 AUTHOR
# 2                                          None                   None
# 3                   Business & Utility Services                 DESIGN
# 4                                          None                   None
# 5                                Content & Apps                    APP
# 6   Personal Goods & General Merchandise Stores               CLOTHING
# 7   Personal Goods & General Merchandise Stores  TOPIC_SHOPPING_RETAIL
# 8                        Creators & Celebrities                 ARTIST
# 9                        Creators & Celebrities          PERSONAL_BLOG
# 10  Personal Goods & General Merchandise Stores  TOPIC_SHOPPING_RETAIL
# 11                                         None                   None
# 12  Personal Goods & General Merchandise Stores  TOPIC_SHOPPING_RETAIL
# 13                                         None                   None
# 14                                         None                   None
# 15  Personal Goods & General Merchandise Stores               CLOTHING
# 16  Personal Goods & General Merchandise Stores        PRODUCT_SERVICE
# 17                                         None                   None
# 18                                         None                   None
# 19                             General Interest                  MEDIA
# 20                                         None                   None
# 21                             General Interest                    ART
# 22                  Business & Utility Services                   None
# 23                                         None                   None
# 24                                         None                   None
# 25                                   Publishers     MEDIA_NEWS_COMPANY
# 26                                         None                   None
# 27  Personal Goods & General Merchandise Stores                   None
# 28                       Creators & Celebrities        DIGITAL_CREATOR
# 29  Personal Goods & General Merchandise Stores                   None
# 30  Personal Goods & General Merchandise Stores                   None
# 31                  Business & Utility Services                 DESIGN
# 32  Personal Goods & General Merchandise Stores        PRODUCT_SERVICE
# 33                                   Publishers               MAGAZINE
# 34                                         None                   None
# 35  Personal Goods & General Merchandise Stores              BABY_KIDS
# 36  Personal Goods & General Merchandise Stores               CLOTHING
# 37                                         None                   None
# 38  Personal Goods & General Merchandise Stores        JEWELRY_WATCHES
# 39                 Grocery & Convenience Stores                 BAKERY
# 40                             General Interest                   None
# 41                                         None                   None
# 42                        Professional Services      EDUCATION_COMPANY
# 43                                         None                   None
# 44                       Creators & Celebrities       FASHION_DESIGNER
# 45  Personal Goods & General Merchandise Stores        PRODUCT_SERVICE
# 46                                         None                   None
# 47  Personal Goods & General Merchandise Stores        PRODUCT_SERVICE
# 48                                         None                   None
# 49                                         None                   None
# 50                                         None                   None
# 51  Personal Goods & General Merchandise Stores                WEBSITE
# 52                                         None                   None
# 53  Personal Goods & General Merchandise Stores          VINTAGE_STORE
# 54  Personal Goods & General Merchandise Stores               CLOTHING
#
#                                   category_name  v_media_count  i_media_count  \
# 0   Personal Goods & General Merchandise Stores              0            340
# 1                        Creators & Celebrities              7           2126
# 2                                          None              4            593
# 3                   Business & Utility Services              0             82
# 4                                          None              0             14
# 5                                Content & Apps             67           2055
# 6   Personal Goods & General Merchandise Stores             27           2775
# 7   Personal Goods & General Merchandise Stores             33           1777
# 8                        Creators & Celebrities             30             32
# 9                        Creators & Celebrities            765           6784
# 10  Personal Goods & General Merchandise Stores             68           1691
# 11                                         None              0             25
# 12  Personal Goods & General Merchandise Stores              6            593
# 13                                         None             10            523
# 14                                         None              0            176
# 15  Personal Goods & General Merchandise Stores              0            179
# 16  Personal Goods & General Merchandise Stores             44            996
# 17                                         None              0             40
# 18                                         None            161            484
# 19                             General Interest            773          12379
# 20                                         None              3            300
# 21                             General Interest              0            514
# 22                  Business & Utility Services              0             75
# 23                                         None              0              4
# 24                                         None             64           1613
# 25                                   Publishers            579           7908
# 26                                         None              1            675
# 27  Personal Goods & General Merchandise Stores              5            348
# 28                       Creators & Celebrities              3             62
# 29  Personal Goods & General Merchandise Stores              1             66
# 30  Personal Goods & General Merchandise Stores              0            122
# 31                  Business & Utility Services              0            423
# 32  Personal Goods & General Merchandise Stores             19           1835
# 33                                   Publishers              0              1
# 34                                         None              3            270
# 35  Personal Goods & General Merchandise Stores              0            218
# 36  Personal Goods & General Merchandise Stores              1           1599
# 37                                         None              0             76
# 38  Personal Goods & General Merchandise Stores              0            137
# 39                 Grocery & Convenience Stores             16            220
# 40                             General Interest             21           1046
# 41                                         None              0             54
# 42                        Professional Services              5            187
# 43                                         None              2            316
# 44                       Creators & Celebrities              3            722
# 45  Personal Goods & General Merchandise Stores             45           3741
# 46                                         None           1432          22396
# 47  Personal Goods & General Merchandise Stores              0            495
# 48                                         None              5            844
# 49                                         None              6            668
# 50                                         None              0            516
# 51  Personal Goods & General Merchandise Stores              1           1130
# 52                                         None              1            166
# 53  Personal Goods & General Merchandise Stores              0           5835
# 54  Personal Goods & General Merchandise Stores              0             95
#
#     is_private                                    profile_pic_url
# 0        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 1        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 2        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 3        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 4        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 5        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 6        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 7        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 8        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 9        False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 10       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 11       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 12       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 13       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 14       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 15       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 16       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 17       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 18       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 19       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 20       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 21       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 22       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 23       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 24       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 25       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 26       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 27       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 28       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 29       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 30       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 31       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 32       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 33       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 34       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 35       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 36       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 37       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 38       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 39       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 40       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 41       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 42       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 43       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 44       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 45       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 46       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 47       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 48       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 49       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 50       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 51       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 52       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 53       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 54       False  https://scontent-nrt1-1.cdninstagram.com/v/t51...

# %%
df1.to_csv('./{}/profile/_Profile종합_.csv'.format(keyword), encoding='utf-8-sig')

# %%
url = contents['graphql']['user']['profile_pic_url'] #url

import requests
import shutil #이미지저장

os.makedirs('./{}/'.format('img'),exist_ok=True) #하위폴더 생성

try :
    response = requests.get(url, stream = True)
    local_file = open(f'./img/임시.jpg','wb') #저장임시파일
    response.raw.decode_content = True #역할이...?
    shutil.copyfileobj(response.raw, local_file)
    #             print(f'{index}, 이미지저장')
    image = 1
except Exception as ex:
#             print(f'{index}, 이미지저장실패')
#             print(ex) 
    image = 0
    pass

# %%
###영상만
#v_m_count = [] # 영상 게시글 개수.
v_m_type = [] # 게시글 타입
v_m_id = []  # 게시글 고유 id
v_m_owner_id = [] # 이미지 게시자 id
v_m_username = [] # 게시글 username
v_m_tagged_id = [] # 태그한 계정 id
v_m_tagged_profile_url = []  # 태그한 계정 프로필 url
v_m_tagged_username = [] # 태그한 계정 username
v_m_url = [] # 영상 url
video_view_count = [] #영상 조회수
v_edge_text = [] # 게시글에 같이 올라간 text
v_comment_count = [] # 영상 댓글수
v_m_timestamp = [] # 타임스탬프
v_liked = [] #영상좋아요수
v_thumbnail = [] # 썸네일 url

###이미지만
i_m_count = [] # 이미지 게시글 개수
i_m_type = [] # 이미지 게시글 타입
i_m_id = []  # 게시글 고유 id
i_m_owner_id = [] #게시자 id
i_m_tagged_id = [] # 태그한 계정 id
i_m_tagged_profile_url = []  # 태그한 계정 프로필 url
i_m_tagged_username = [] # 태그한 계정 username
i_m_caption = [] #인스타에서 부여해주는 캡션
i_m_text = [] # 작성자가 작성하는 텍스트
i_m_shortcode = [] #게시글에 부여되는 쇼트코드
i_comment_count = [] #댓글 수
i_m_timestamp = [] #타임스탬프
i_liked = [] #좋아요수
i_thumbnail = [] #썸네일url

# %%
os.makedirs('./{}/profile/v_media'.format(keyword),exist_ok=True) #하위폴더 생성

# %%
for i in range(0,len(files)):
    json_file_path = "G:/_2021/kCP/_파이널프로젝트/팀/data/test/profile/" + files[i] + ".json"
                    #G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/
                    #E:/2021/KCP/팀원/수집/test/feed/1916953364/
    with open(json_file_path,'r', encoding="utf-8") as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
    v_count = len(contents['graphql']['user']['edge_felix_video_timeline']['edges'])
    
    for j in range(0,v_count+1): #동영상 게시글 개수
        
#         try:
#             v_m_type.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['__typename'])
#         except:
#             v_m_type.append('-')
#         try:
#             v_m_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['id'])
#         except:
#             v_m_id.append('-')
#         try:
#             v_m_owner_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['owner']['id'])
#         except:
#             v_m_owner_id.append('-')
#         try:
#             v_m_username.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['owner']['username'])
#         except:
#             v_m_username.append('-')
        
#         try:
#             v_m_tagged_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'][k]['node']['user']['id'])
#         except:
#             v_m_tagged_id.append('-')
#         try:
#             v_m_tagged_profile_url.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'][k]['node']['user']['profile_pic_url'])
#         except:
#             v_m_tagged_profile_url.append('-')
#         try:
#             v_m_tagged_username.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'][k]['node']['user']['username'])
#         except:
#             v_m_tagged_username.append('-')
        try:
            t_count = len(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'])
        except:
            t_count = 0
        for k in range(0,t_count+1):  # 태그 계정 개수
#             v_m_type.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['__typename'])
#             v_m_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['id'] )
#             v_m_owner_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'][0]['node']['user']['id'])
#             v_m_username.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['owner']['username'])
#             v_m_type.append('-')
#             v_m_id.append('-')
#             v_m_owner_id.append('-')
#             v_m_username.append('-')
            try:
                v_m_type.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['__typename'])
            except:
                v_m_type.append('-')
            try:
                v_m_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['id'])
            except:
                v_m_id.append('-')
            try:
                v_m_owner_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['owner']['id'])
            except:
                v_m_owner_id.append('-')
            try:
                v_m_username.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['owner']['username'])
            except:
                v_m_username.append('-')        
    
            try:
                v_m_tagged_id.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'][k]['node']['user']['id'])
            except:
                v_m_tagged_id.append('-')
            try:
                v_m_tagged_profile_url.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'][k]['node']['user']['profile_pic_url'])
            except:
                v_m_tagged_profile_url.append('-')
            try:
                v_m_tagged_username.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_tagged_user']['edges'][k]['node']['user']['username'])
            except:
                v_m_tagged_username.append('-')
#             v_m_url.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['video_url'])
#             video_view_count.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['video_view_count'])
#             v_edge_text.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_caption']['edges'][0]['node']['text'])
#             v_comment_count.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_comment']['count'])
#             v_m_timestamp.append(convert_datetime(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['taken_at_timestamp']))
#             v_liked.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_liked_by']['count'])
#             v_tumbnail.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['thumbnail_src'])
#             v_m_url.append('-')
#             video_view_count.append('-')
#             v_edge_text.append('-')
#             v_comment_count.append('-')
#             v_m_timestamp.append('-')
#             v_liked.append('-')
#             v_thumbnail.append('-')
            try:
                v_m_url.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['video_url'])
            except:
                v_m_url.append('-')
            try:
                video_view_count.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['video_view_count'])
            except:
                video_view_count.append('-')
            try:
                v_edge_text.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_caption']['edges'][0]['node']['text'])
            except:
                v_edge_text.append('-')
            try:
                v_comment_count.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_media_to_comment']['count'])
            except:
                v_comment_count.append('-')
            try:
                v_m_timestamp.append(convert_datetime(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['taken_at_timestamp']))
            except:
                v_m_timestamp.append('-')
            try:
                v_liked.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['edge_liked_by']['count'])
            except:
                v_liked.append('-')
            try:
                v_thumbnail.append(contents['graphql']['user']['edge_felix_video_timeline']['edges'][j]['node']['thumbnail_src'])
            except:
                v_thumbnail.append('-')

#     print(len(v_m_type), len(v_m_id), len(v_m_owner_id), len(v_m_username), len(v_m_tagged_id), len(v_m_tagged_profile_url), len(v_m_tagged_username),\
#          len(v_m_url),len(video_view_count),len(v_edge_text),len(v_comment_count),len(v_m_timestamp),len(v_liked),len(v_thumbnail))
#     print("----------------------------------------------")
df2 = pd.DataFrame({"v_m_type":v_m_type, "v_m_id":v_m_id, "v_m_owner_id":v_m_owner_id, "v_m_username":v_m_username, \
                       "v_m_tagged_id":v_m_tagged_id, "v_m_tagged_profile_url":v_m_tagged_profile_url, "v_m_tagged_username":v_m_tagged_username,\
                       "v_m_url":v_m_url, "video_view_count":video_view_count, "v_edge_text":v_edge_text,\
                       "v_comment_count":v_comment_count, "v_m_timestamp":v_m_timestamp, "v_liked":v_liked, "v_thumbnail":v_thumbnail})

#df2.to_csv('./{}/profile/v_media/{}_profile_v_media.csv'.format(keyword,files[i][8:]), encoding='utf-8-sig')
df2
# Out:
#        v_m_type               v_m_id v_m_owner_id v_m_username v_m_tagged_id  \
# 0             -                    -            -            -             -
# 1    GraphVideo  1887812153249221449   5566945015      0.218kg             -
# 2    GraphVideo  1818923134726087268   5566945015      0.218kg             -
# 3    GraphVideo  1750124276223316030   5566945015      0.218kg             -
# 4    GraphVideo  1749937373791990742   5566945015      0.218kg             -
# ..          ...                  ...          ...          ...           ...
# 381           -                    -            -            -             -
# 382  GraphVideo  1052160322966157368   1580807589    suabaragi             -
# 383           -                    -            -            -             -
# 384           -                    -            -            -             -
# 385           -                    -            -            -             -
#
#     v_m_tagged_profile_url v_m_tagged_username  \
# 0                        -                   -
# 1                        -                   -
# 2                        -                   -
# 3                        -                   -
# 4                        -                   -
# ..                     ...                 ...
# 381                      -                   -
# 382                      -                   -
# 383                      -                   -
# 384                      -                   -
# 385                      -                   -
#
#                                                v_m_url video_view_count  \
# 0                                                    -                -
# 1    https://scontent-nrt1-1.cdninstagram.com/v/t50...              425
# 2    https://scontent-nrt1-1.cdninstagram.com/v/t50...              344
# 3    https://scontent-nrt1-1.cdninstagram.com/v/t50...              383
# 4    https://scontent-nrt1-1.cdninstagram.com/v/t50...              262
# ..                                                 ...              ...
# 381                                                  -                -
# 382  https://scontent-nrt1-1.cdninstagram.com/v/t50...                0
# 383                                                  -                -
# 384                                                  -                -
# 385                                                  -                -
#
#                                            v_edge_text v_comment_count  \
# 0                                                    -               -
# 1    -\n.\n.\n그대와 그때\n그대와 그땐\n그랬었는데\n그대는 그때를 그리워할까요...               1
# 2                                   다양한 요리로 당신을 사로잡는다!               1
# 3    .🔊음악이 나옵니다 마음에 볼륨을 올려주세요🔊\n.\n떠났다 네가 내게서\n왜 마음...               0
# 4    .🔊음악이 나옵니다 마음에 볼륨을 올려주세요🔊\n.\n널 잊고 싶지 않았고\n널 잃...               2
# ..                                                 ...             ...
# 381                                                  -               -
# 382  .\n눈으로 보는게 훨씬 멋있움😍\n\n#여의도 #불꽃축제 #맞팔 #선팔 #소통 #...              16
# 383                                                  -               -
# 384                                                  -               -
# 385                                                  -               -
#
#     v_m_timestamp v_liked                                        v_thumbnail
# 0               -       -                                                  -
# 1      2018-10-11     116  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 2      2018-07-08      19  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 3      2018-04-04      97  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 4      2018-04-04     107  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# ..            ...     ...                                                ...
# 381             -       -                                                  -
# 382    2015-08-15     280  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 383             -       -                                                  -
# 384             -       -                                                  -
# 385             -       -                                                  -
#
# [386 rows x 14 columns]

# %%
df2.to_csv('./{}/profile/_Profile_v_media.csv'.format(keyword), encoding='utf-8-sig')

# %%
json_file_path = "E:/2021/KCP/팀원/수집/test/profile/" + files[1] + ".json"
with open(json_file_path,'r', encoding="utf-8") as j:
    contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드

# %%
contents['graphql']['user']['edge_felix_video_timeline']['edges'][0]['node']['id']
# Out:
# '1887812153249221449'

# %%
#총 게시글 개수
media_count = contents['graphql']['user']['edge_owner_to_timeline_media']['count']
media_count
# Out:
# 6784

# %%
# 게시글 타입
media_type = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['__typename']
# Out:
# 'GraphImage'

# %%
# 게시글에 부여된 id, 12개 있음
for i in range(0, len(contents['graphql']['user']['edge_owner_to_timeline_media']['edges'])):
    a = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][i]['node']['id'] 
    print(a)
# Out:
# 2645720734840998028
# 2645066528056604526
# 2644480697486975749
# 2644400578974076663
# 2644284582133135906
# 2644184389412915914
# 2644153955492802424
# 2643722155284996882
# 2643554708082818385
# 2643466246537116703
# 2642768698734410966
# 2642203353279700505

# %%
#게시글 작성자 id 12개 있음
media_owner_id = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['owner']['id'] 
media_owner_id
# Out:
# '1297647769'

# %%
#게시글 썸네일 url
media_thumbnail_src = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['thumbnail_src']
# Out:
# 'https://scontent-nrt1-1.cdninstagram.com/v/t51.2885-15/e35/54513133_420938518451405_1123517740237390229_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com&_nc_cat=105&_nc_ohc=3CgdPNQ_xoAAX_fEyMU&tn=Ev3WHxChEHpDDXag&edm=ABfd0MgBAAAA&ccb=7-4&oh=363e525560a9243d6e45405488c40223&oe=61295C25&_nc_sid=7bff83'

# %%
# 태그한 계정 없을 수도 있음
# 태그한 계쩡 id
contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][11]['node']['edge_media_to_tagged_user']['edges'][0]['node']['user']['id']
# Out:
# '2235322963'

# %%
# 태그한 계정 profile_pic_url
contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][11]['node']['edge_media_to_tagged_user']['edges'][0]['node']['user']['profile_pic_url']
# Out:
# 'https://scontent-nrt1-1.cdninstagram.com/v/t51.2885-19/s150x150/139578248_3572423569539303_6975432386994604876_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com&_nc_ohc=XJTiDb_T2TUAX9kXsr8&edm=ABfd0MgBAAAA&ccb=7-4&oh=0975e91b2a7ac7090b624d236e271002&oe=61295B79&_nc_sid=7bff83'

# %%
# 태그한 계정 username
contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][11]['node']['edge_media_to_tagged_user']['edges'][0]['node']['user']['username']
# Out:
# 'mastergarage1550'

# %%
 #인스타에서 부여해주는 캡션
contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['accessibility_caption']
# Out:
# 'Photo by 데일리룩, 패션, 남자패션, 유니섹스 / 룩잇 on March 28, 2019. May be an image of one or more people, people standing and outerwear.'

# %%
#작성자가 작성한 텍스트
owner_text = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_caption']['edges'][0]['node']['text']
# Out:
# '[ 울 하프 폴라 니트 ]\n-\n주문은 스토어팜에서 가능합니다🎁\n-\n#남성패션 #코디 #셀카 #데일리룩 #데일리코디 #패션스타그램 #옷스타그램 #셀스타그램 #쇼핑몰 #오오티디 #룩잇 #니트웨어 #하프폴라 #팔로우 #소통 #소통해요 #선팔 #일상 #맞팔 #룩잇 #감성 #인친 #daily #f4f #l4l #dailylook #menswear #ootd'

# %%
 #미디어에 부여된 쇼트코드
media_shortcode = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['shortcode']
# Out:
# 'BvkxOOYF3gY'

# %%
#댓글수
comments_count = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_media_to_comment']['count']
# Out:
# 7

# %%
#게시글 업로드 시간
timestamp = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['taken_at_timestamp'] 
convert_datetime(timestamp)
# Out:
# '2021-08-22'

# %%
#좋아요 수
media_like = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['edge_liked_by']['count']
# Out:
# 76

# %%
#게시글 썸네일 url
media_thumbnail_src = contents['graphql']['user']['edge_owner_to_timeline_media']['edges'][0]['node']['thumbnail_src']
# Out:
# 'https://scontent-nrt1-1.cdninstagram.com/v/t51.2885-15/e35/54513133_420938518451405_1123517740237390229_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com&_nc_cat=105&_nc_ohc=3CgdPNQ_xoAAX_fEyMU&tn=Ev3WHxChEHpDDXag&edm=ABfd0MgBAAAA&ccb=7-4&oh=363e525560a9243d6e45405488c40223&oe=61295C25&_nc_sid=7bff83'

# %% [markdown]
# ### topsearch 폴더 조지기

# %%
os.makedirs('./{}/topsearch'.format(keyword),exist_ok=True) #하위폴더 생성

# %%
json_file_path = "G:/_2021/kCP/_파이널프로젝트/팀/data/test/topsearch/topsearch_@패션.json"
                    #G:/_2021/kCP/_파이널프로젝트/팀/data/test/feed/1916953364/
                    #E:/2021/KCP/팀원/수집/test/feed/1916953364/
with open(json_file_path,'r', encoding="utf-8") as j:
    contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드

# %%
contents['users'][0]['user']
# Out:
# {'pk': '30316172873',
#  'username': 'joysstyles_',
#  'full_name': 'JOY FASHION | 조이 패션',
#  'is_private': False,
#  'profile_pic_url': 'https://scontent-nrt1-1.cdninstagram.com/v/t51.2885-19/s150x150/201895537_565046271535950_6979536994323395130_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com&_nc_ohc=KZHzbFzk8CYAX_tBx9P&edm=AHG7ALcBAAAA&ccb=7-4&oh=f91b686f671e79493f82fde9f986fb32&oe=6129BBDF&_nc_sid=5cbaad',
#  'profile_pic_id': '2597301135565163988_30316172873',
#  'is_verified': False,
#  'follow_friction_type': 0,
#  'has_anonymous_profile_picture': False,
#  'account_badges': [],
#  'friendship_status': {'following': False,
#   'is_private': False,
#   'incoming_request': False,
#   'outgoing_request': False,
#   'is_bestie': False,
#   'is_restricted': False},
#  'latest_reel_media': 1629632357,
#  'live_broadcast_id': None}

# %%
contents['users'][1]['user']['profile_pic_id']
# Out:
# '2206014563772633019_1916953364'

# %%
inf_pk=[]
inf_username=[]
# full_name=[]
# is_private=[]
# profile_pic_url=[]
# profile_pic_id=[]
# is_verified=[]
# follow_friction_type=[]
# has_anonymous_profile_picture=[]
# account_badges=[]
# #friendship_status=[]
# following=[]
# is_private=[]
# incoming_request=[]
# outgoing_request=[]
# is_bestie=[]
# is_restricted=[]
# latest_reel_media=[]
# live_broadcast_id=[]

# %%
for i in range(len(contents['users'])):
    pk.append(contents['users'][i]['user']['pk'])
    username.append(contents['users'][i]['user']['username'])
#     full_name.append(contents['users'][i]['user']['full_name'])
#     is_private.append(contents['users'][i]['user']['is_private'])
#     profile_pic_url.append(contents['users'][i]['user']['profile_pic_url'])
#     try:
#         profile_pic_id.append(contents['users'][i]['user']['profile_pic_id'])
#     except:
#         profile_pic_id.append('')
#     is_verified.append(contents['users'][i]['user']['is_verified'])
#     follow_friction_type.append(contents['users'][i]['user']['follow_friction_type'])
#     has_anonymous_profile_picture.append(contents['users'][i]['user']['has_anonymous_profile_picture'])
#     account_badges.append(contents['users'][i]['user']['account_badges'])
#     #friendship_status.append(contents['users'][i]['user']['friendship_status'])
#     for j in range(len(contents['users'][i]['user']['friendship_status'])):     
#         following.append(contents['users'][i]['user']['friendship_status']['following'])
#         is_private.append(contents['users'][i]['user']['friendship_status']['is_private'])
#         incoming_request.append(contents['users'][i]['user']['friendship_status']['incoming_request'])
#         outgoing_request.append(contents['users'][i]['user']['friendship_status']['outgoing_request'])
#         is_bestie.append(contents['users'][i]['user']['friendship_status']['is_bestie'])  
#         is_restricted.append(contents['users'][i]['user']['friendship_status']['is_restricted'])
#     latest_reel_media.append(contents['users'][i]['user']['latest_reel_media'])
#     live_broadcast_id.append(contents['users'][i]['user']['live_broadcast_id'])

# %%
df=pd.DataFrame({"inf_pk":inf_pk, "inf_username":inf_username})
df
# Out:
#              pk                  username
# 0   30316172873               joysstyles_
# 1    1916953364            dailylook.book
# 2     435680883             shinseunghun_
# 3   26039066648               final_scene
# 4    3500614932  fashionandstyle.official
# 5   38769156492         styleby.redvelvet
# 6   35641698457           irenebaefashion
# 7    7489768030            vintage_bbadda
# 8    4752827967                fuckit9982
# 9   13284579121                shoe_prize
# 10   2494123960     insight.co.kr_fashion
# 11   1996261596                 style_88_
# 12  38980901318         dailyfashion_news
# 13   2016264755      fashionista_styling_
# 14   5566945015                   0.218kg
# 15   1580807589                 suabaragi
# 16  22566228417           k_fashion_looks
# 17   2103025565              myeongjaunni
# 18   3411103232          pictorial.sensio
# 19   6704185900                  muto2148
# 20  40961995563               bang_outfit
# 21  29325677496              yerikimstyle
# 22   1394688376                 bsha_bsha
# 23   2043464728                style_mans
# 24   1651957095               crushj_yeon
# 25  45906937921                aespastyle
# 26   5870333100                  photoly7
# 27   1374816594                 hyesuk.go
# 28    614515131                 knock_the
# 29  15202623986             seulgistyles_
# 30  35803666192             jungwoostyles
# 31   2218550660          brandi__official
# 32  44756465001          styleby.ohmygirl
# 33  42934449545           canyon.pictures
# 34   3865979785            fashion_theqoo
# 35  44377137381          fashion_9woori_s
# 36   1019962414                   soulssa
# 37  48646162911             lake_magazine
# 38  20225518661           leeboyoungstyle
# 39   5010150517         nobling_official1
# 40  48077165346             fingersuit_kr
# 41   1563788188                 cane_bros
# 42   2296309794         passion5_official
# 43   4057123831              elecom_korea
# 44   1297647769               coolguy9283
# 45   4639396333             mianmian_bebe
# 46   3885671730                juniac1118
# 47  46526656287                dangmihyi2
# 48  46088894392             daily_liny_98
# 49   1505962480          style.editor_34p
# 50  48962855780                   banshoi
# 51   8005180162               __look_it__
# 52   2227621116           placesimulation
# 53  24401827886                  jungan_u
# 54    866947432            ddins_official

# %%
df.to_csv('./{}/topsearch/topsearch_@패션.csv'.format(keyword), encoding='utf-8-sig')
